# %% [markdown]
# # Set up and test connection to spotify via spotipy

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import getpass
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from tqdm import tqdm

# %%
client_id=str(getpass.getpass('client_id?'))
client_secret=str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %% [markdown]
# # Activity 3 - dictionary with song id: name, artists from a playlist

# %%
def get_all(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results ['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    id2=[]
    artist=[]
    song=[]
    for i in range(len(tracks)):
        song.append(tracks[i]['track']['name'])
        artist.append(tracks[i]['track']['artists'][0]['name'])
        id2.append(tracks[i]['track']['id'])
    dict = {id2[i]: (song[i], artist[i]) for i in range(len(id2))}
    audio_feats = []
    for x in tqdm(range(len(tracks))):
        audio_feats.extend(sp.audio_features(tracks=tracks[x]['track']['id']))
    df_name = pd.DataFrame(audio_feats)
    return df_name

# %%
def songsinfo(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results ['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    id2=[]
    artist=[]
    song=[]
    for i in range(len(tracks)):
        song.append(tracks[i]['track']['name'])
        artist.append(tracks[i]['track']['artists'][0]['name'])
        id2.append(tracks[i]['track']['id'])
    dataframe=pd.DataFrame(list(zip(id2, artist, song)),columns=['ids','names', 'artist'])
    return dataframe

# %%
user_id = 'Marc Puyol Iniesta'
playlist_id = '7rhMKhFN0TKgbEYYF6iPNC'
Legends = get_all(user_id,playlist_id)
Legends_songs=songsinfo(user_id, playlist_id)
# Out:
# 100%|█████████████████████████████████████████| 182/182 [00:10<00:00, 17.82it/s]

# %%
Legends_songs
# Out:
#                         ids               names  \
# 0    5l9c6bJmzvftumhz4TMPgk          Neil Young
# 1    5IRWgQiN0c2i4U97iE3OoY          Neil Young
# 2    4RIp4UTguC0F6TRV7xfKjv          Neil Young
# 3    5yrsBzgHkfu2idkl2ILQis           Jim Croce
# 4    51ueZKM83MTRv9rgiDfI6Y           Jim Croce
# ..                      ...                 ...
# 177  0j3p1p06deJ7f9xmJ9yG22         The Beatles
# 178  3BQHpFgAp4l80e1XslIjNI         The Beatles
# 179  6KOtheMY0KN4s9TrQHr9It  The Rolling Stones
# 180  7wCmS9TTVUcIhRalDYFgPy              Pixies
# 181  5BpWVTgEQTng1ocwMsVzZO                Blur
#
#                                      artist
# 0                              Harvest Moon
# 1             Heart of Gold - 2017 Remaster
# 2                   Old Man - 2017 Remaster
# 3            You Don't Mess Around with Jim
# 4                   Walkin' Back to Georgia
# ..                                      ...
# 177  Back In The U.S.S.R. - Remastered 2009
# 178             Yesterday - Remastered 2009
# 179                         She's A Rainbow
# 180          Where Is My Mind? - Remastered
# 181                              To the End
#
# [182 rows x 3 columns]

# %%
user_id = 'analeovy'
playlist_id = '34SD82fF4iCGO2EuDhFZsp'
An_optimist = get_all(user_id,playlist_id)
An_optimist_songs=songsinfo(user_id, playlist_id)
# Out:
# 100%|███████████████████████████████████████████| 33/33 [00:05<00:00,  5.72it/s]

# %%
user_id = 'yurrmommia'
playlist_id = '0DAQ5ppelxMSSfXBNLxT45'
Best2000 = get_all(user_id,playlist_id)
Best2000_songs =songsinfo(user_id, playlist_id)
# Out:
# 100%|███████████████████████████████████████| 1991/1991 [03:16<00:00, 10.12it/s]

# %%
user_id = 'Natasha Bannister'
playlist_id = '1ViETlRgr1EtVa9oDO8Vpb'
allgenres = get_all(user_id,playlist_id)
allgenres_songs=songsinfo(user_id, playlist_id)
# Out:
# 100%|███████████████████████████████████████| 1566/1566 [02:34<00:00, 10.13it/s]

# %%
user_id = 'Marc Puyol Iniesta'
playlist_id = '0y0QntvocWdHZD7WY1R5iO'
Todomarcus = get_all(user_id,playlist_id)
Todomarcus_songs =songsinfo(user_id, playlist_id)
# Out:
# 100%|███████████████████████████████████████| 1839/1839 [02:57<00:00, 10.36it/s]

# %%
user_id = 'Billboard'
playlist_id = '6UeSakyzhiEt4NB3UAd6NQ'
Billboard = get_all(user_id,playlist_id)
Billboard_songs =songsinfo(user_id, playlist_id)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:08<00:00, 11.16it/s]

# %%
allmusic=pd.concat([Legends, An_optimist,Best2000,Todomarcus,allgenres], sort = False, ignore_index=True)
allmusic_songs=pd.concat([Legends_songs, An_optimist_songs,Best2000_songs,Todomarcus_songs,allgenres_songs])

# %%
allmusic=allmusic.drop_duplicates()
allmusic =allmusic.reset_index(drop=True)

# %%
allmusic_songs=allmusic_songs.drop_duplicates()
allmusic_songs=allmusic_songs.reset_index(drop=True)

# %%
allmusic
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.648   0.309    2   -12.432     1       0.0264        0.5260
# 1            0.542   0.444    4   -11.567     0       0.0295        0.2120
# 2            0.709   0.278    4   -13.011     0       0.0353        0.4600
# 3            0.705   0.581   11   -11.379     0       0.0455        0.6070
# 4            0.661   0.518    6   -10.061     0       0.0319        0.6210
# ...            ...     ...  ...       ...   ...          ...           ...
# 5182         0.895   0.694    9    -4.384     1       0.2750        0.1760
# 5183         0.678   0.857   10    -5.173     0       0.2160        0.0325
# 5184         0.889   0.818    9    -4.639     1       0.2530        0.4700
# 5185         0.925   0.744    0    -5.790     1       0.3670        0.0644
# 5186         0.782   0.846    9    -5.070     0       0.1170        0.1420
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000249    0.1240    0.407  112.929  audio_features
# 1             0.051900    0.1020    0.827  171.719  audio_features
# 2             0.007190    0.0980    0.458  141.268  audio_features
# 3             0.000015    0.1170    0.967  163.240  audio_features
# 4             0.000018    0.0953    0.776  127.266  audio_features
# ...                ...       ...      ...      ...             ...
# 5182          0.000000    0.2920    0.632   93.944  audio_features
# 5183          0.000000    0.0788    0.622   94.950  audio_features
# 5184          0.000000    0.1790    0.782   96.063  audio_features
# 5185          0.000000    0.0888    0.656   93.020  audio_features
# 5186          0.000000    0.0408    0.917  126.061  audio_features
#
#                           id                                   uri  \
# 0     5l9c6bJmzvftumhz4TMPgk  spotify:track:5l9c6bJmzvftumhz4TMPgk
# 1     5IRWgQiN0c2i4U97iE3OoY  spotify:track:5IRWgQiN0c2i4U97iE3OoY
# 2     4RIp4UTguC0F6TRV7xfKjv  spotify:track:4RIp4UTguC0F6TRV7xfKjv
# 3     5yrsBzgHkfu2idkl2ILQis  spotify:track:5yrsBzgHkfu2idkl2ILQis
# 4     51ueZKM83MTRv9rgiDfI6Y  spotify:track:51ueZKM83MTRv9rgiDfI6Y
# ...                      ...                                   ...
# 5182  6Tsu3OsuMz4KEGKbOYd6A0  spotify:track:6Tsu3OsuMz4KEGKbOYd6A0
# 5183  2NeHnSFnwNp1Z5WYgcjJ8L  spotify:track:2NeHnSFnwNp1Z5WYgcjJ8L
# 5184  3xX9hoGEq1EuMGWZl8LQL1  spotify:track:3xX9hoGEq1EuMGWZl8LQL1
# 5185  0jSMveIWvnhDIvzqN74Uc7  spotify:track:0jSMveIWvnhDIvzqN74Uc7
# 5186  0XSxvknneLhfyRv0g7ka7t  spotify:track:0XSxvknneLhfyRv0g7ka7t
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5l9c6bJmzvft...
# 1     https://api.spotify.com/v1/tracks/5IRWgQiN0c2i...
# 2     https://api.spotify.com/v1/tracks/4RIp4UTguC0F...
# 3     https://api.spotify.com/v1/tracks/5yrsBzgHkfu2...
# 4     https://api.spotify.com/v1/tracks/51ueZKM83MTR...
# ...                                                 ...
# 5182  https://api.spotify.com/v1/tracks/6Tsu3OsuMz4K...
# 5183  https://api.spotify.com/v1/tracks/2NeHnSFnwNp1...
# 5184  https://api.spotify.com/v1/tracks/3xX9hoGEq1Eu...
# 5185  https://api.spotify.com/v1/tracks/0jSMveIWvnhD...
# 5186  https://api.spotify.com/v1/tracks/0XSxvknneLhf...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5l9c...       303213
# 1     https://api.spotify.com/v1/audio-analysis/5IRW...       187013
# 2     https://api.spotify.com/v1/audio-analysis/4RIp...       202400
# 3     https://api.spotify.com/v1/audio-analysis/5yrs...       184640
# 4     https://api.spotify.com/v1/audio-analysis/51ue...       170760
# ...                                                 ...          ...
# 5182  https://api.spotify.com/v1/audio-analysis/6Tsu...       230000
# 5183  https://api.spotify.com/v1/audio-analysis/2NeH...       219253
# 5184  https://api.spotify.com/v1/audio-analysis/3xX9...       302760
# 5185  https://api.spotify.com/v1/audio-analysis/0jSM...       243227
# 5186  https://api.spotify.com/v1/audio-analysis/0XSx...       179093
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 5182               4
# 5183               4
# 5184               4
# 5185               4
# 5186               4
#
# [5187 rows x 18 columns]

# %%
allmusic_songs
# Out:
#                          ids                 names  \
# 0     5l9c6bJmzvftumhz4TMPgk            Neil Young
# 1     5IRWgQiN0c2i4U97iE3OoY            Neil Young
# 2     4RIp4UTguC0F6TRV7xfKjv            Neil Young
# 3     5yrsBzgHkfu2idkl2ILQis             Jim Croce
# 4     51ueZKM83MTRv9rgiDfI6Y             Jim Croce
# ...                      ...                   ...
# 5182  6Tsu3OsuMz4KEGKbOYd6A0  The Notorious B.I.G.
# 5183  2NeHnSFnwNp1Z5WYgcjJ8L                   DMX
# 5184  3xX9hoGEq1EuMGWZl8LQL1  The Notorious B.I.G.
# 5185  0jSMveIWvnhDIvzqN74Uc7                J-Kwon
# 5186  0XSxvknneLhfyRv0g7ka7t              Infernal
#
#                                  artist
# 0                          Harvest Moon
# 1         Heart of Gold - 2017 Remaster
# 2               Old Man - 2017 Remaster
# 3        You Don't Mess Around with Jim
# 4               Walkin' Back to Georgia
# ...                                 ...
# 5182          Hypnotize - 2007 Remaster
# 5183               X Gon' Give It To Ya
# 5184              Juicy - 2005 Remaster
# 5185                   Tipsy - Club Mix
# 5186  From Paris To Berlin - Radio Edit
#
# [5187 rows x 3 columns]

# %%
allmusic=allmusic.drop(columns=['analysis_url', 'track_href','uri','type'])

# %%
allmusic
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.648   0.309    2   -12.432     1       0.0264        0.5260
# 1            0.542   0.444    4   -11.567     0       0.0295        0.2120
# 2            0.709   0.278    4   -13.011     0       0.0353        0.4600
# 3            0.705   0.581   11   -11.379     0       0.0455        0.6070
# 4            0.661   0.518    6   -10.061     0       0.0319        0.6210
# ...            ...     ...  ...       ...   ...          ...           ...
# 5182         0.895   0.694    9    -4.384     1       0.2750        0.1760
# 5183         0.678   0.857   10    -5.173     0       0.2160        0.0325
# 5184         0.889   0.818    9    -4.639     1       0.2530        0.4700
# 5185         0.925   0.744    0    -5.790     1       0.3670        0.0644
# 5186         0.782   0.846    9    -5.070     0       0.1170        0.1420
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000249    0.1240    0.407  112.929  5l9c6bJmzvftumhz4TMPgk
# 1             0.051900    0.1020    0.827  171.719  5IRWgQiN0c2i4U97iE3OoY
# 2             0.007190    0.0980    0.458  141.268  4RIp4UTguC0F6TRV7xfKjv
# 3             0.000015    0.1170    0.967  163.240  5yrsBzgHkfu2idkl2ILQis
# 4             0.000018    0.0953    0.776  127.266  51ueZKM83MTRv9rgiDfI6Y
# ...                ...       ...      ...      ...                     ...
# 5182          0.000000    0.2920    0.632   93.944  6Tsu3OsuMz4KEGKbOYd6A0
# 5183          0.000000    0.0788    0.622   94.950  2NeHnSFnwNp1Z5WYgcjJ8L
# 5184          0.000000    0.1790    0.782   96.063  3xX9hoGEq1EuMGWZl8LQL1
# 5185          0.000000    0.0888    0.656   93.020  0jSMveIWvnhDIvzqN74Uc7
# 5186          0.000000    0.0408    0.917  126.061  0XSxvknneLhfyRv0g7ka7t
#
#       duration_ms  time_signature
# 0          303213               4
# 1          187013               4
# 2          202400               4
# 3          184640               4
# 4          170760               4
# ...           ...             ...
# 5182       230000               4
# 5183       219253               4
# 5184       302760               4
# 5185       243227               4
# 5186       179093               4
#
# [5187 rows x 14 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
index_name=allmusic.iloc[:,11]
index_name
# Out:
# 0       5l9c6bJmzvftumhz4TMPgk
# 1       5IRWgQiN0c2i4U97iE3OoY
# 2       4RIp4UTguC0F6TRV7xfKjv
# 3       5yrsBzgHkfu2idkl2ILQis
# 4       51ueZKM83MTRv9rgiDfI6Y
#                  ...
# 5182    6Tsu3OsuMz4KEGKbOYd6A0
# 5183    2NeHnSFnwNp1Z5WYgcjJ8L
# 5184    3xX9hoGEq1EuMGWZl8LQL1
# 5185    0jSMveIWvnhDIvzqN74Uc7
# 5186    0XSxvknneLhfyRv0g7ka7t
# Name: id, Length: 5187, dtype: object

# %%
allmusic=allmusic.drop(columns=['id'])

# %%
allmusic.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5182    False
# 5183    False
# 5184    False
# 5185    False
# 5186    False
# Length: 5187, dtype: bool

# %% [markdown]
# # Audio Features

# %%
# get track list with url uri or ID for each track 
# run audio-features query

# %%
scaler=StandardScaler()

# %%
scaler.fit(allmusic)
# Out:
# StandardScaler()

# %%
allmusic_scaled=scaler.transform(allmusic)

# %%
allmusic_scaled_df=pd.DataFrame(allmusic_scaled, columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature'])

# %%
allmusic_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  5.187000e+03  5.187000e+03  5.187000e+03  5.187000e+03  5.187000e+03
# mean  -2.329606e-16  2.798353e-16 -8.929729e-17 -4.936822e-16  3.745264e-16
# std    1.000096e+00  1.000096e+00  1.000096e+00  1.000096e+00  1.000096e+00
# min   -4.038487e+00 -2.667529e+00 -1.429036e+00 -6.495930e+00 -1.702939e+00
# 25%   -6.204357e-01 -7.054986e-01 -8.638503e-01 -4.946762e-01 -1.702939e+00
# 50%    7.545491e-02  1.555876e-01 -1.607189e-02  2.372178e-01  5.872202e-01
# 75%    6.928873e-01  8.275464e-01  8.317066e-01  7.063238e-01  5.872202e-01
# max    2.545184e+00  1.722008e+00  1.679485e+00  1.837256e+00  5.872202e-01
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  5.187000e+03  5.187000e+03      5.187000e+03  5.187000e+03
# mean   2.283374e-16 -2.626265e-17      1.067651e-15 -3.469581e-17
# std    1.000096e+00  1.000096e+00      1.000096e+00  1.000096e+00
# min   -9.433091e-01 -9.744795e-01     -2.661859e-01 -1.086126e+00
# 25%   -4.856020e-01 -8.775245e-01     -2.661859e-01 -5.792266e-01
# 50%   -3.572208e-01 -4.199752e-01     -2.661658e-01 -3.954668e-01
# 75%   -1.114960e-02  8.378545e-01     -2.634145e-01  2.078199e-01
# max    1.178318e+01  2.139544e+00      6.026793e+00  5.630466e+00
#
#             valence         tempo   duration_ms  time_signature
# count  5.187000e+03  5.187000e+03  5.187000e+03    5.187000e+03
# mean   4.178052e-16 -1.231744e-16 -1.171438e-16    1.377762e-15
# std    1.000096e+00  1.000096e+00  1.000096e+00    1.000096e+00
# min   -2.144808e+00 -4.209414e+00 -3.341202e+00   -1.213581e+01
# 25%   -7.909445e-01 -7.507526e-01 -5.584145e-01    1.901047e-01
# 50%   -2.060651e-02 -2.017879e-02 -1.186883e-01    1.901047e-01
# 75%    7.833157e-01  5.949502e-01  3.894706e-01    1.901047e-01
# max    1.990248e+00  3.447601e+00  1.049317e+01    3.271583e+00

# %%
allmusic_scaled_df.hist(bins=15, figsize=(15,15));

# %%
K_Means=KMeans(n_clusters=8, random_state=5) #use consistent Random State

# %%
cluster_data_sc=K_Means.fit(allmusic_scaled_df)

# %%
cluster_data_sc.cluster_centers_
# Out:
# array([[-3.31477467e-01, -1.24527414e+00, -5.75811434e-02,
#         -9.95539985e-01,  2.24091918e-01, -3.33749280e-01,
#          1.30952527e+00, -1.62989186e-01, -2.78403458e-01,
#         -6.59782685e-01, -2.95802932e-01,  1.22187691e-04,
#          2.80031086e-01],
#        [ 5.62081297e-01,  4.93051436e-01, -5.05885814e-02,
#          3.83457500e-01,  5.87220220e-01, -1.64795432e-01,
#         -4.59968309e-01, -2.19378968e-01, -1.85287282e-01,
#          7.34072827e-01, -1.71983241e-01, -2.58560436e-01,
#          1.74697292e-01],
#        [-8.58897752e-02,  5.06588069e-01,  3.08491837e-02,
#          2.87268575e-01,  1.11904231e-01,  1.62612678e-01,
#         -2.76810896e-01, -2.05578788e-01,  3.05042404e+00,
#          2.45112765e-01,  2.07995133e-02,  9.85656621e-02,
#          1.78476464e-01],
#        [ 5.21217574e-01,  1.10212080e-01,  1.81373371e-03,
#          5.64430617e-02, -2.22995020e-03,  3.54974006e+00,
#         -7.83474000e-02, -1.93306248e-01,  1.05727225e-01,
#          2.83281057e-01,  2.14019622e-01, -1.41221657e-01,
#          1.38096614e-01],
#        [-4.25246828e-01, -3.35930564e-01, -9.09918432e-02,
#         -9.30814409e-01, -5.18938799e-02, -2.85702427e-01,
#          3.80592706e-01,  4.41076401e+00, -2.35280574e-01,
#         -5.10412790e-01, -4.79937218e-02,  3.56638201e-01,
#         -5.35470734e-02],
#        [-7.42781187e-01,  4.40381021e-01, -4.79087087e-02,
#          4.69848234e-01,  4.72845271e-01, -1.81117144e-01,
#         -5.83305089e-01, -1.92655483e-01, -1.08046500e-01,
#         -5.65677183e-01,  5.71367982e-01,  3.89029046e-01,
#          2.15157350e-01],
#        [-9.01178679e-01, -1.00905609e+00,  8.14078641e-02,
#         -6.90110797e-01,  1.56319250e-01, -2.79347952e-01,
#          8.77861029e-01, -1.27321570e-01, -9.94458371e-02,
#         -7.34977620e-01,  2.34897656e-01,  2.71659958e-01,
#         -3.33158457e+00],
#        [ 4.95165767e-01,  4.61028875e-01,  1.77697012e-01,
#          4.37045854e-01, -1.70293864e+00, -1.45773424e-02,
#         -4.94251662e-01, -1.91187027e-01, -1.29378589e-01,
#          3.64863009e-01, -6.75809622e-02, -1.34663306e-01,
#          1.90104683e-01]])

# %%
cluster_data_sc.labels_
# Out:
# array([0, 7, 0, ..., 3, 3, 7], dtype=int32)

# %%
allmusic_scaled_df['cluster_no']=cluster_data_sc.labels_

# %%
allmusic_scaled_df['cluster_no'].value_counts()
# Out:
# 1    1402
# 0    1031
# 7     894
# 5     856
# 6     287
# 2     265
# 3     237
# 4     215
# Name: cluster_no, dtype: int64

# %%
allmusic_scaled_df
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         0.382465 -1.348532 -0.863850 -1.361433  0.587220    -0.574911
# 1        -0.340715 -0.747774 -0.298665 -1.121400 -1.702939    -0.531652
# 2         0.798635 -1.486484 -0.298665 -1.522103 -1.702939    -0.450716
# 3         0.771346 -0.138116  1.679485 -1.069230 -1.702939    -0.308380
# 4         0.471157 -0.418470  0.266521 -0.703491 -1.702939    -0.498161
# ...            ...       ...       ...       ...       ...          ...
# 5182      2.067612  0.364740  1.114299  0.871850  0.587220     2.894174
# 5183      0.587139  1.090100  1.396892  0.652906 -1.702939     2.070859
# 5184      2.026678  0.916548  1.114299  0.801088  0.587220     2.587175
# 5185      2.272286  0.587243 -1.429036  0.481691  0.587220     4.177986
# 5186      1.296675  1.041149  1.114299  0.681488 -1.702939     0.689365
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0         0.673381         -0.264575 -0.360795 -0.436211 -0.264169
# 1        -0.310326          0.069483 -0.513350  1.326960  1.789696
# 2         0.466615         -0.219684 -0.541088 -0.222112  0.725871
# 3         0.927140         -0.266088 -0.409335  1.914684  1.493477
# 4         0.971000         -0.266071 -0.559810  1.112861  0.236703
# ...            ...               ...       ...       ...       ...
# 5182     -0.423108         -0.266186  0.804172  0.508345 -0.927422
# 5183     -0.872669         -0.266186 -0.674227  0.466365 -0.892277
# 5184      0.497943         -0.266186  0.020593  1.138049 -0.853393
# 5185     -0.772731         -0.266186 -0.604884  0.609098 -0.959703
# 5186     -0.529624         -0.266186 -0.937731  1.704783  0.194605
#
#       duration_ms  time_signature  cluster_no
# 0        1.401493        0.190105           0
# 1       -0.619317        0.190105           7
# 2       -0.351725        0.190105           0
# 3       -0.660585        0.190105           7
# 4       -0.901970        0.190105           7
# ...           ...             ...         ...
# 5182     0.128261        0.190105           3
# 5183    -0.058638        0.190105           7
# 5184     1.393615        0.190105           3
# 5185     0.358289        0.190105           3
# 5186    -0.757052        0.190105           7
#
# [5187 rows x 14 columns]

# %%
allmusic_scaled_df['id']=index_name

# %%
allmusic_scaled_df
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         0.382465 -1.348532 -0.863850 -1.361433  0.587220    -0.574911
# 1        -0.340715 -0.747774 -0.298665 -1.121400 -1.702939    -0.531652
# 2         0.798635 -1.486484 -0.298665 -1.522103 -1.702939    -0.450716
# 3         0.771346 -0.138116  1.679485 -1.069230 -1.702939    -0.308380
# 4         0.471157 -0.418470  0.266521 -0.703491 -1.702939    -0.498161
# ...            ...       ...       ...       ...       ...          ...
# 5182      2.067612  0.364740  1.114299  0.871850  0.587220     2.894174
# 5183      0.587139  1.090100  1.396892  0.652906 -1.702939     2.070859
# 5184      2.026678  0.916548  1.114299  0.801088  0.587220     2.587175
# 5185      2.272286  0.587243 -1.429036  0.481691  0.587220     4.177986
# 5186      1.296675  1.041149  1.114299  0.681488 -1.702939     0.689365
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0         0.673381         -0.264575 -0.360795 -0.436211 -0.264169
# 1        -0.310326          0.069483 -0.513350  1.326960  1.789696
# 2         0.466615         -0.219684 -0.541088 -0.222112  0.725871
# 3         0.927140         -0.266088 -0.409335  1.914684  1.493477
# 4         0.971000         -0.266071 -0.559810  1.112861  0.236703
# ...            ...               ...       ...       ...       ...
# 5182     -0.423108         -0.266186  0.804172  0.508345 -0.927422
# 5183     -0.872669         -0.266186 -0.674227  0.466365 -0.892277
# 5184      0.497943         -0.266186  0.020593  1.138049 -0.853393
# 5185     -0.772731         -0.266186 -0.604884  0.609098 -0.959703
# 5186     -0.529624         -0.266186 -0.937731  1.704783  0.194605
#
#       duration_ms  time_signature  cluster_no                      id
# 0        1.401493        0.190105           0  5l9c6bJmzvftumhz4TMPgk
# 1       -0.619317        0.190105           7  5IRWgQiN0c2i4U97iE3OoY
# 2       -0.351725        0.190105           0  4RIp4UTguC0F6TRV7xfKjv
# 3       -0.660585        0.190105           7  5yrsBzgHkfu2idkl2ILQis
# 4       -0.901970        0.190105           7  51ueZKM83MTRv9rgiDfI6Y
# ...           ...             ...         ...                     ...
# 5182     0.128261        0.190105           3  6Tsu3OsuMz4KEGKbOYd6A0
# 5183    -0.058638        0.190105           7  2NeHnSFnwNp1Z5WYgcjJ8L
# 5184     1.393615        0.190105           3  3xX9hoGEq1EuMGWZl8LQL1
# 5185     0.358289        0.190105           3  0jSMveIWvnhDIvzqN74Uc7
# 5186    -0.757052        0.190105           7  0XSxvknneLhfyRv0g7ka7t
#
# [5187 rows x 15 columns]

# %% [markdown]
# # Finding the right K

# %%
allmusic_scaled_df2=allmusic_scaled_df.drop(['cluster_no','id'],axis=1)

# %%
allmusic_scaled_df2.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
K=range(5,18)
inertia=[]
for k in K:
    kmeans=KMeans(n_clusters=k,random_state=5)
    kmeans.fit(allmusic_scaled_df2)
    inertia.append(kmeans.inertia_)

# %%
#plot the resulting inertia - elbow 
plt.figure(figsize=(16,8))
plt.plot(K,inertia,'bx-')
plt.xlabel('k=noofclusters')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('elbow method inertia to find optimal K');

# %%
K=range(5,18)
sil=[]
for k in K:
    kmeans=KMeans(n_clusters=k,random_state=5)
    kmeans.fit(allmusic_scaled_df2)
    sil.append(silhouette_score(allmusic_scaled_df2,kmeans.predict(allmusic_scaled_df2)))
#silhouette score 
# if 1 - the clusters are very separated from eachother and clearly distinguished
# if 0 - clusters are indifferent - the distance between them are not significant and you cannot distinguish
# if -1 clusters are incorrectly assigned

# %%
#plot the resulting silhouette 
plt.figure(figsize=(16,8))
plt.plot(K,sil,'bo-')
plt.xlabel('k=noofclusters')
plt.ylabel('silhouette')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('silhouette score');

# %%
allmusic_songs=pd.concat([allmusic_scaled_df,allmusic_songs], axis=1)

# %%
allmusic_songs['names']=allmusic_songs['names'].str.lower()
allmusic_songs['artist']=allmusic_songs['artist'].str.lower()

# %%
allmusic_songs['artist'][0]
# Out:
# 'harvest moon'

# %%
allmusic_songs
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         0.382465 -1.348532 -0.863850 -1.361433  0.587220    -0.574911
# 1        -0.340715 -0.747774 -0.298665 -1.121400 -1.702939    -0.531652
# 2         0.798635 -1.486484 -0.298665 -1.522103 -1.702939    -0.450716
# 3         0.771346 -0.138116  1.679485 -1.069230 -1.702939    -0.308380
# 4         0.471157 -0.418470  0.266521 -0.703491 -1.702939    -0.498161
# ...            ...       ...       ...       ...       ...          ...
# 5182      2.067612  0.364740  1.114299  0.871850  0.587220     2.894174
# 5183      0.587139  1.090100  1.396892  0.652906 -1.702939     2.070859
# 5184      2.026678  0.916548  1.114299  0.801088  0.587220     2.587175
# 5185      2.272286  0.587243 -1.429036  0.481691  0.587220     4.177986
# 5186      1.296675  1.041149  1.114299  0.681488 -1.702939     0.689365
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0         0.673381         -0.264575 -0.360795 -0.436211 -0.264169
# 1        -0.310326          0.069483 -0.513350  1.326960  1.789696
# 2         0.466615         -0.219684 -0.541088 -0.222112  0.725871
# 3         0.927140         -0.266088 -0.409335  1.914684  1.493477
# 4         0.971000         -0.266071 -0.559810  1.112861  0.236703
# ...            ...               ...       ...       ...       ...
# 5182     -0.423108         -0.266186  0.804172  0.508345 -0.927422
# 5183     -0.872669         -0.266186 -0.674227  0.466365 -0.892277
# 5184      0.497943         -0.266186  0.020593  1.138049 -0.853393
# 5185     -0.772731         -0.266186 -0.604884  0.609098 -0.959703
# 5186     -0.529624         -0.266186 -0.937731  1.704783  0.194605
#
#       duration_ms  time_signature  cluster_no                      id  \
# 0        1.401493        0.190105           0  5l9c6bJmzvftumhz4TMPgk
# 1       -0.619317        0.190105           7  5IRWgQiN0c2i4U97iE3OoY
# 2       -0.351725        0.190105           0  4RIp4UTguC0F6TRV7xfKjv
# 3       -0.660585        0.190105           7  5yrsBzgHkfu2idkl2ILQis
# 4       -0.901970        0.190105           7  51ueZKM83MTRv9rgiDfI6Y
# ...           ...             ...         ...                     ...
# 5182     0.128261        0.190105           3  6Tsu3OsuMz4KEGKbOYd6A0
# 5183    -0.058638        0.190105           7  2NeHnSFnwNp1Z5WYgcjJ8L
# 5184     1.393615        0.190105           3  3xX9hoGEq1EuMGWZl8LQL1
# 5185     0.358289        0.190105           3  0jSMveIWvnhDIvzqN74Uc7
# 5186    -0.757052        0.190105           7  0XSxvknneLhfyRv0g7ka7t
#
#                          ids                 names  \
# 0     5l9c6bJmzvftumhz4TMPgk            neil young
# 1     5IRWgQiN0c2i4U97iE3OoY            neil young
# 2     4RIp4UTguC0F6TRV7xfKjv            neil young
# 3     5yrsBzgHkfu2idkl2ILQis             jim croce
# 4     51ueZKM83MTRv9rgiDfI6Y             jim croce
# ...                      ...                   ...
# 5182  6Tsu3OsuMz4KEGKbOYd6A0  the notorious b.i.g.
# 5183  2NeHnSFnwNp1Z5WYgcjJ8L                   dmx
# 5184  3xX9hoGEq1EuMGWZl8LQL1  the notorious b.i.g.
# 5185  0jSMveIWvnhDIvzqN74Uc7                j-kwon
# 5186  0XSxvknneLhfyRv0g7ka7t              infernal
#
#                                  artist
# 0                          harvest moon
# 1         heart of gold - 2017 remaster
# 2               old man - 2017 remaster
# 3        you don't mess around with jim
# 4               walkin' back to georgia
# ...                                 ...
# 5182          hypnotize - 2007 remaster
# 5183               x gon' give it to ya
# 5184              juicy - 2005 remaster
# 5185                   tipsy - club mix
# 5186  from paris to berlin - radio edit
#
# [5187 rows x 18 columns]

# %% [markdown]
# # Is it a hot song?

# %%
import Levenshtein as lev
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import numpy as np
import requests
import re
from bs4 import BeautifulSoup
from IPython.display import display

# %%
url= "https://www.billboard.com/charts/hot-100/"

# %%
results=requests.get(url)

# %%
soup=BeautifulSoup(results.content, 'html.parser')

# %%
title=[]
artist=[]
len_songs=len(soup.select("li.o-chart-results-list__item h3"))
for i in range(len_songs):
    title.append(soup.select("li.o-chart-results-list__item  h3")[i].text.replace("\n",""))
    artist.append(soup.select('li.o-chart-results-list__item span.c-label.a-font-primary-s')[i].get_text(strip=True))

# %%
songs=pd.DataFrame({"Song_title":title, "artist":artist})

# %%
songs['song_rank']=np.arange(len(songs))+1

# %%
songs["Song_title"] = songs["Song_title"].str.lower()
songs["artist"] = songs["artist"].str.lower()
songs
# Out:
#                          Song_title  \
# 0         we don't talk about bruno
# 1                        heat waves
# 2                           abcdefu
# 3                        easy on me
# 4                     super gremlin
# ..                              ...
# 95                           closer
# 96                    cold december
# 97                get into it (yuh)
# 98  all too well (taylor's version)
# 99            give heaven some hell
#
#                                                artist  song_rank
# 0   carolina gaitan, mauro castillo, adassa, rhenz...          1
# 1                                       glass animals          2
# 2                                               gayle          3
# 3                                               adele          4
# 4                                         kodak black          5
# ..                                                ...        ...
# 95                          saweetie featuring h.e.r.         96
# 96                                           rod wave         97
# 97                                           doja cat         98
# 98                                       taylor swift         99
# 99                                              hardy        100
#
# [100 rows x 3 columns]

# %%
list[songs['Song_title']]
# Out:
# list[0           we don't talk about bruno
# 1                          heat waves
# 2                             abcdefu
# 3                          easy on me
# 4                       super gremlin
#                    ...
# 95                             closer
# 96                      cold december
# 97                  get into it (yuh)
# 98    all too well (taylor's version)
# 99              give heaven some hell
# Name: Song_title, Length: 100, dtype: object]

# %%
from colorama import Fore

def second_suggester():
    songs2, artist = input(f'{Fore.BLUE}What is the song you are thinking of? ').lower(), input(f"{Fore.BLUE}Who is the artist of the song(leave it blank if you don't know it?").lower()
    if songs2 in songs.values:
        index_song = list(songs['Song_title']).index(songs2)
        list_art=re.split(",",songs['artist'][index_song])
        if artist in list_art: 
            print(f'{Fore.GREEN}Are these the songs and artists you were looking for?')
            print(str(songs['Song_title'][index_song]))
            print(str(songs['artist'][index_song]))
            Checking= input(f'{Fore.BLUE}yes or no? ')
            if Checking=='yes':
                print("\nThis song and artist are trendy now")
                print("These are the trendy songs by the artist right now:")
                display(songs.loc[songs['artist'] == ''.join(list_art)]) 
                print("You may also like these other trendy songs:")
                print(str(songs['Song_title'].sample(2).to_string(index=False)))
            
            elif Checking=='no':
                print('Please start again')
                second_suggester()
            else:
                print('Please start again')
                second_suggester()
                                
        elif artist=='':
            print("\nThis song is trendy now and it's interpreted by " + str((songs['artist'][index_song])))
            print("You may also like this songs from the same artist:")
            display(songs.loc[songs['artist'] == ''.join(list_art)])
        else: 
            print("\nThe songs exists but the artist is not in the list")
    else:

        if artist in songs.values: 
            index_song = list(songs['artist']).index(artist)
            list_art=re.split(",",songs['artist'][index_song])
            print("\nThese are the trendy songs from this artist: ")
            display(songs.loc[songs['artist'] == ''.join(list_art)])

        else:
            x=process.extractOne(songs2,songs['Song_title'],scorer=fuzz.token_set_ratio)
            print("where you asking for this song" + str(x) + '?')
            Question=input('yes or no? ')
            if Question=='yes':
                print("\nThis song is trendy" + str(x))
            if Question=='no':
                if songs2 in allmusic_songs.values: 
                    index_song2 = list(allmusic_songs['artist']).index(songs2)
                    list_art=re.split(",",allmusic_songs['names'][index_song2])
                    print("\nIs this the song you were looking for?"+ str((allmusic_songs['artist'][index_song2])))
                    Question2=input('yes or no?')
                    if Question2=='yes':
                        print("I'm glad you found the song you were looking for. You may also find interesting:") 
                        print(str(allmusic_songs['artist'][allmusic_songs.cluster_no==allmusic_songs['cluster_no'][index_song2]].sample(1).to_string(index=False)))
                else:
                    if artist in allmusic_songs.values:
                        index_song3 = list(allmusic_songs['names']).index(artist)
                        list_art=re.split(",",allmusic_songs['artist'][index_song3])
                        print("\nIs this one of the songs you were looking for?")
                        print(str(allmusic_songs['artist'].loc[allmusic_songs['names'] == artist]))
                        second_suggester()
                    else: 
                        track_id = sp.search(q='artist:' + input('artist') + ' track:' + input('song'), type='track', limit=1)
                        x = track_id["tracks"]['items'][0]['id']
                        audio_feat=pd.DataFrame(sp.audio_features(tracks=x))
                        new_row=pd.DataFrame(data=audio_feat)
                        new_row_num=new_row.drop(columns=['type','id', 'uri', 'track_href','analysis_url'])
                        new_row_scaled=scaler.transform(new_row_num)
                        new_row_scaled_df=pd.DataFrame(new_row_scaled, columns=[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms','time_signature']])
                        x=cluster_data_sc.predict(new_row_scaled_df)
                        x=str(x)
                        x=x.replace('[','').replace(']','')
                        print(str(allmusic_songs['artist'][allmusic_songs.cluster_no==int(x)].sample(2).to_string(index=False)))
                        
            else:
                print('')

# %%
second_suggester()
# Out:
# What is the song you are thinking of? asdas
# Who is the artist of the song(leave it blank if you don't know it?asdasd
# where you asking for this song('aa', 57, 52)?
# yes or no? no
# artistoasis
# songwonderwall
# wall of glass
#     dieciocho
# /Users/marcpuyoliniesta/opt/anaconda3/envs/ClassMarc/lib/python3.9/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# /Users/marcpuyoliniesta/opt/anaconda3/envs/ClassMarc/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
