# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Dropping-unrelevant-columns-and-null-values" data-toc-modified-id="Dropping-unrelevant-columns-and-null-values-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Dropping unrelevant columns and null values</a></span><ul class="toc-item"><li><span><a href="#Filling-null-values" data-toc-modified-id="Filling-null-values-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Filling null values</a></span></li><li><span><a href="#Standarizing-data-(Transforming-M-to-millons-and-k-to-thousands)" data-toc-modified-id="Standarizing-data-(Transforming-M-to-millons-and-k-to-thousands)-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Standarizing data (Transforming M to millons and k to thousands)</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
leaning=pd.read_excel('diezprimerostiktok5.xlsx')

# %% [markdown]
# # Dropping unrelevant columns and null values

# %%
leaning=leaning.drop(columns=['Unnamed: 30', 'Unnamed: 31','Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 28', 'Twitch'])

# %%
null_columns=leaning.columns[leaning.isnull().any()]
leaning[null_columns].isnull().sum()
# Out:
# Country                13
# Totalfollowers          7
# followerspain          13
# authenticengament       9
# Account2                9
# Links                   9
# Category                1
# Subcategory           307
# Subcategory 2         830
# Subcategory 3        1026
# Unnamed: 11          1061
# Country.1               9
# Marcas1               191
# Marcas2               238
# Marcas3               248
# Marcas4               260
# Marcas5               266
# Marcas6               275
# Marcas7               280
# Marcas8               282
# Marcas9               293
# Marcas10              305
# Unnamed: 23          1020
# Tik Tok               832
# Youtube               879
# Twitter               790
# %offemales             50
# dtype: int64

# %%
cleaning = leaning.dropna(axis=0, subset=['Country'])

# %%
null_columns=cleaning.columns[cleaning.isnull().any()]
cleaning[null_columns].isnull().sum()
# Out:
# followerspain       4
# Subcategory       304
# Subcategory 2     819
# Subcategory 3    1013
# Unnamed: 11      1048
# Marcas1           181
# Marcas2           228
# Marcas3           238
# Marcas4           250
# Marcas5           256
# Marcas6           265
# Marcas7           270
# Marcas8           273
# Marcas9           282
# Marcas10          294
# Unnamed: 23      1007
# Tik Tok           822
# Youtube           869
# Twitter           778
# %offemales         43
# dtype: int64

# %%
cleaning.loc[cleaning['followerspain'].isnull(),:]
# Out:
#      Country              Name Totalfollowers followerspain authenticengament  \
# 1005   Spain  gracyvillarreal          628900           NaN          15030.71
# 1011   Spain    sofia_suescun         1300000           NaN             37180
# 1023   Spain          manurios        9800000           NaN            954520
# 1035   Spain      laura_somoza          63800           NaN             97614
#
#              Account2                                             Links  \
# 1005  gracyvillarreal  https://www.instagram.com/gracyvillarreal/?hl=es
# 1011    sofia_suescun    https://www.instagram.com/sofia_suescun/?hl=es
# 1023         manurios         https://www.instagram.com/manurios/?hl=es
# 1035     laura_somoza     https://www.instagram.com/laura_somoza/?hl=es
#
#      Category         Subcategory              Subcategory 2 Subcategory 3  \
# 1005  Fashion            Modeling                        NaN           NaN
# 1011  Fashion           Lifestyle                        NaN           NaN
# 1023  Fashion            Modeling  Cinema & actors/actresses           NaN
# 1035  Fashion  Clothing & Outfits                        NaN           NaN
#
#       Unnamed: 11 Country.1             Marcas1                Marcas2  \
# 1005          NaN     spain             @mango,    @melissavillarreal,
# 1011          NaN     spain     @sheinofficial,  @ayadamaldivesresort,
# 1023          NaN     spain  @allnightproducer,              @mmscene,
# 1035          NaN     spain            @cartier        @thefrankieshop
#
#             Marcas3        Marcas4              Marcas5               Marcas6  \
# 1005     @guerlain,  @jake_henson,    @thevillaconcept,   @salonmonchomoreno,
# 1011    @montealoe,      @desenio,            @w.carss,  @inglotspainoficial,
# 1023      @moncler,   @oppoespana,           @manurios,        @yachtlifeapp,
# 1035   @belleamienw    @ynesuelves   @bassinsdelumieres           @anclademar
#
#                 Marcas7           Marcas8         Marcas9  \
# 1005         @ghdspain,   @chanel.beauty,  @benefitspain,
# 1011  @ismaelbachiller,           @guess,     @tonsanmar,
# 1023          @twojeys,    @elitenetflix,     @netflixes,
# 1035            @sezane   @simonuptonpics    @midnight00_
#
#                  Marcas10 Unnamed: 23  Tik Tok  Youtube Twitter %offemales
# 1005      @angelescaceres         NaN      NaN      NaN     NaN    ,78.7 %
# 1011  @albinadylaofficial         NaN      NaN      NaN     NaN    ,55.6 %
# 1023             @gqspain         NaN  2900000  1730000     NaN    ,55.2 %
# 1035          @adakokosar         NaN      NaN      NaN     NaN   ,Unknown

# %%
cleaning['followerspain']= cleaning['followerspain'].fillna('Unknown')
# Out:
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_12331/3003599862.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaning['followerspain']= cleaning['followerspain'].fillna('Unknown')

# %%
cleaning=cleaning.drop(columns=['Unnamed: 11'])

# %%
cleaning=cleaning.drop(columns=['Unnamed: 23'])

# %%
null_columns=cleaning.columns[cleaning.isnull().any()]
cleaning[null_columns].isnull().sum()
# Out:
# Subcategory       304
# Subcategory 2     819
# Subcategory 3    1013
# Marcas1           181
# Marcas2           228
# Marcas3           238
# Marcas4           250
# Marcas5           256
# Marcas6           265
# Marcas7           270
# Marcas8           273
# Marcas9           282
# Marcas10          294
# Tik Tok           822
# Youtube           869
# Twitter           778
# %offemales         43
# dtype: int64

# %% [markdown]
# ## Filling null values

# %%
cleaning=cleaning.fillna('Unknown')

# %%
cleaning
# Out:
#             Country                 Name Totalfollowers followerspain  \
# 0     United States       Kendall Jenner         223.4M         12.9M
# 1     United States      Kim Kardashian          291.7M         13.4M
# 2     United States             Beyoncé          242.6M         11.8M
# 3             Spain  Georgina Rodriguez           36.2M          3.1M
# 4            Turkey      Barbara Palvin           17.4M        915.9K
# ...             ...                  ...            ...           ...
# 1056          Spain          Evelin Nora          17,9K         17,9K
# 1057          Spain    Ángeles Rodríguez          34,3K          8918
# 1058          Spain        Lucía Segovia          44,6k         22000
# 1059          Spain       Clara Martínez          73,7K         40535
# 1060          Spain       Aurora Artacho          35,7K         24000
#
#      authenticengament           Account2  \
# 0                 3.1M      kendalljenner
# 1                 2.1M      kimkardashian
# 2                 2.6M            beyonce
# 3                 2.3M        georginagio
# 4               540.8K  realbarbarapalvin
# ...                ...                ...
# 1056             0.019         evelinnora
# 1057            0.0157         martiylola
# 1058            0.0475         luciasegva
# 1059            0.0317     claaramartinez
# 1060            0.0313      auroraartacho
#
#                                                   Links Category  \
# 0        https://www.instagram.com/kendalljenner/?hl=es  Fashion
# 1        https://www.instagram.com/kimkardashian/?hl=es  Fashion
# 2              https://www.instagram.com/beyonce/?hl=es  Fashion
# 3          https://www.instagram.com/georginagio/?hl=es  Fashion
# 4     https://www.instagram.com/realbarbarapalvin/?h...  Fashion
# ...                                                 ...      ...
# 1056        https://www.instagram.com/evelinnora/?hl=es  Fashion
# 1057        https://www.instagram.com/martiylola/?hl=es  Fashion
# 1058        https://www.instagram.com/luciasegva/?hl=es  Fashion
# 1059    https://www.instagram.com/claaramartinez/?hl=es  Fashion
# 1060     https://www.instagram.com/auroraartacho/?hl=es  Fashion
#
#              Subcategory       Subcategory 2 Subcategory 3 Country.1  \
# 0              Lifestyle  Clothing & Outfits       Unknown     italy
# 1                 Beauty    Actors/actresses       Unknown     italy
# 2                  Music             Unknown       Unknown     italy
# 3              Lifestyle  Clothing & Outfits       Unknown     italy
# 4               Modeling             Unknown       Unknown     italy
# ...                  ...                 ...           ...       ...
# 1056  Clothing & Outfits             Unknown       Unknown     spain
# 1057  Clothing & Outfits             Unknown       Unknown     spain
# 1058  Clothing & Outfits             Unknown       Unknown     spain
# 1059  Clothing & Outfits             Unknown       Unknown     spain
# 1060  Clothing & Outfits             Unknown       Unknown     spain
#
#                 Marcas1                Marcas2                Marcas3  \
# 0                @moon,          @calvinklein,        @voguemagazine,
# 1      @chrisappleton1,  @letthelordbewithyou,      @khloekardashian,
# 2      @billybiohazard,         @monacosalons,  @jerryroperoofficial,
# 3           @cristiano,         @dolcegabbana,        @pasqualebruni,
# 4     @victoriassecret,         @armanibeauty,            @owengould,
# ...                 ...                    ...                    ...
# 1056        @degustabox         @kaptenandson,  @womensecretofficial,
# 1057            Unknown                Unknown                Unknown
# 1058   @nataliapachecov        @nachomendez21,  @showroomprive_spain,
# 1059            @mrboho  @noa_lapetitemaltais,                    @s,
# 1060      @guada_losada          @jysk_espana,       @esteelauder_es,
#
#                   Marcas4            Marcas5          Marcas6  \
# 0          @haileybieber,        @zazaworld,   @danielcaesar,
# 1           @marcmhoward,           @oxygen,   @kkwfragrance,
# 2            @uplydance_,         @greatist,  @victoriamonet,
# 3       @ermannoscervino,      @bellacanvas,       @less_app,
# 4     @suspiciousantwerp,  @thelovemagazine,    @colesprouse,
# ...                   ...                ...              ...
# 1056    @daisy_jewellery,       @nescafe_es,   @fatalelondon,
# 1057              Unknown            Unknown          Unknown
# 1058      @bryanstepwise,  @lokitashandmade,   @donasoljoyas,
# 1059       @mrwonderful_,   @blackboughswim,  @maybelline_es,
# 1060         @lmburguete,       @evans.foto,     @mb_talents,
#
#                   Marcas7                   Marcas8              Marcas9  \
# 0           @dominicfike,                @bakarrrr,   @matthewmwilliams,
# 1                 @skims,              @krisjenner,    @rickowensonline,
# 2         @itsamanuworld,  @isabelleboireau_beauty,        @chloexhalle,
# 3     @suspiciousantwerp,            @louisvuitton,    @nicolasgerardin,
# 4               @chillrv,         @mariansellphoto,       @susan_haddon,
# ...                   ...                       ...                  ...
# 1056          @sugarbear,                 @lalalab,    @bosanovaoficial,
# 1057              Unknown                   Unknown              Unknown
# 1058         @luciasegva,     @unrinconmaravilloso,  @northfields_brand,
# 1059          @customima,                 @defreds,        @shein_spain,
# 1060        @cloutespain,             @zacaris_com,      @doctorakarina,
#
#                  Marcas10  Tik Tok   Youtube   Twitter %offemales
# 0         @inezandvinoodh  2300000        No  31900000     50.3 %
# 1           @tracyromulus       No   1880000  71600000    ,53.4 %
# 2           @mstinalawson       NO  24200000  15400000    ,51.7 %
# 3          @stephanebodin       NO        NO        NO    ,50.9 %
# 4     @numero_netherlands       NO        NO   1200000    ,47.1 %
# ...                   ...      ...       ...       ...        ...
# 1056     @andotherstories  Unknown   Unknown   Unknown     65.4 %
# 1057              Unknown  Unknown   Unknown   Unknown    Unknown
# 1058         @alasdesignn  Unknown   Unknown   Unknown     72.4 %
# 1059       @sheinofficial  Unknown   Unknown   Unknown     70.2 %
# 1060    @tuttibeauty.info  Unknown   Unknown   Unknown     76.3 %
#
# [1048 rows x 26 columns]

# %%
cleaning["Totalfollowers"] = cleaning["Totalfollowers"].astype(str)

# %%
cleaning
# Out:
#             Country                 Name Totalfollowers followerspain  \
# 0     United States       Kendall Jenner         223.4M         12.9M
# 1     United States      Kim Kardashian          291.7M         13.4M
# 2     United States             Beyoncé          242.6M         11.8M
# 3             Spain  Georgina Rodriguez           36.2M          3.1M
# 4            Turkey      Barbara Palvin           17.4M        915.9K
# ...             ...                  ...            ...           ...
# 1056          Spain          Evelin Nora          17,9K         17,9K
# 1057          Spain    Ángeles Rodríguez          34,3K          8918
# 1058          Spain        Lucía Segovia          44,6k         22000
# 1059          Spain       Clara Martínez          73,7K         40535
# 1060          Spain       Aurora Artacho          35,7K         24000
#
#      authenticengament           Account2  \
# 0                 3.1M      kendalljenner
# 1                 2.1M      kimkardashian
# 2                 2.6M            beyonce
# 3                 2.3M        georginagio
# 4               540.8K  realbarbarapalvin
# ...                ...                ...
# 1056             0.019         evelinnora
# 1057            0.0157         martiylola
# 1058            0.0475         luciasegva
# 1059            0.0317     claaramartinez
# 1060            0.0313      auroraartacho
#
#                                                   Links Category  \
# 0        https://www.instagram.com/kendalljenner/?hl=es  Fashion
# 1        https://www.instagram.com/kimkardashian/?hl=es  Fashion
# 2              https://www.instagram.com/beyonce/?hl=es  Fashion
# 3          https://www.instagram.com/georginagio/?hl=es  Fashion
# 4     https://www.instagram.com/realbarbarapalvin/?h...  Fashion
# ...                                                 ...      ...
# 1056        https://www.instagram.com/evelinnora/?hl=es  Fashion
# 1057        https://www.instagram.com/martiylola/?hl=es  Fashion
# 1058        https://www.instagram.com/luciasegva/?hl=es  Fashion
# 1059    https://www.instagram.com/claaramartinez/?hl=es  Fashion
# 1060     https://www.instagram.com/auroraartacho/?hl=es  Fashion
#
#              Subcategory       Subcategory 2 Subcategory 3 Country.1  \
# 0              Lifestyle  Clothing & Outfits       Unknown     italy
# 1                 Beauty    Actors/actresses       Unknown     italy
# 2                  Music             Unknown       Unknown     italy
# 3              Lifestyle  Clothing & Outfits       Unknown     italy
# 4               Modeling             Unknown       Unknown     italy
# ...                  ...                 ...           ...       ...
# 1056  Clothing & Outfits             Unknown       Unknown     spain
# 1057  Clothing & Outfits             Unknown       Unknown     spain
# 1058  Clothing & Outfits             Unknown       Unknown     spain
# 1059  Clothing & Outfits             Unknown       Unknown     spain
# 1060  Clothing & Outfits             Unknown       Unknown     spain
#
#                 Marcas1                Marcas2                Marcas3  \
# 0                @moon,          @calvinklein,        @voguemagazine,
# 1      @chrisappleton1,  @letthelordbewithyou,      @khloekardashian,
# 2      @billybiohazard,         @monacosalons,  @jerryroperoofficial,
# 3           @cristiano,         @dolcegabbana,        @pasqualebruni,
# 4     @victoriassecret,         @armanibeauty,            @owengould,
# ...                 ...                    ...                    ...
# 1056        @degustabox         @kaptenandson,  @womensecretofficial,
# 1057            Unknown                Unknown                Unknown
# 1058   @nataliapachecov        @nachomendez21,  @showroomprive_spain,
# 1059            @mrboho  @noa_lapetitemaltais,                    @s,
# 1060      @guada_losada          @jysk_espana,       @esteelauder_es,
#
#                   Marcas4            Marcas5          Marcas6  \
# 0          @haileybieber,        @zazaworld,   @danielcaesar,
# 1           @marcmhoward,           @oxygen,   @kkwfragrance,
# 2            @uplydance_,         @greatist,  @victoriamonet,
# 3       @ermannoscervino,      @bellacanvas,       @less_app,
# 4     @suspiciousantwerp,  @thelovemagazine,    @colesprouse,
# ...                   ...                ...              ...
# 1056    @daisy_jewellery,       @nescafe_es,   @fatalelondon,
# 1057              Unknown            Unknown          Unknown
# 1058      @bryanstepwise,  @lokitashandmade,   @donasoljoyas,
# 1059       @mrwonderful_,   @blackboughswim,  @maybelline_es,
# 1060         @lmburguete,       @evans.foto,     @mb_talents,
#
#                   Marcas7                   Marcas8              Marcas9  \
# 0           @dominicfike,                @bakarrrr,   @matthewmwilliams,
# 1                 @skims,              @krisjenner,    @rickowensonline,
# 2         @itsamanuworld,  @isabelleboireau_beauty,        @chloexhalle,
# 3     @suspiciousantwerp,            @louisvuitton,    @nicolasgerardin,
# 4               @chillrv,         @mariansellphoto,       @susan_haddon,
# ...                   ...                       ...                  ...
# 1056          @sugarbear,                 @lalalab,    @bosanovaoficial,
# 1057              Unknown                   Unknown              Unknown
# 1058         @luciasegva,     @unrinconmaravilloso,  @northfields_brand,
# 1059          @customima,                 @defreds,        @shein_spain,
# 1060        @cloutespain,             @zacaris_com,      @doctorakarina,
#
#                  Marcas10  Tik Tok   Youtube   Twitter %offemales
# 0         @inezandvinoodh  2300000        No  31900000     50.3 %
# 1           @tracyromulus       No   1880000  71600000    ,53.4 %
# 2           @mstinalawson       NO  24200000  15400000    ,51.7 %
# 3          @stephanebodin       NO        NO        NO    ,50.9 %
# 4     @numero_netherlands       NO        NO   1200000    ,47.1 %
# ...                   ...      ...       ...       ...        ...
# 1056     @andotherstories  Unknown   Unknown   Unknown     65.4 %
# 1057              Unknown  Unknown   Unknown   Unknown    Unknown
# 1058         @alasdesignn  Unknown   Unknown   Unknown     72.4 %
# 1059       @sheinofficial  Unknown   Unknown   Unknown     70.2 %
# 1060    @tuttibeauty.info  Unknown   Unknown   Unknown     76.3 %
#
# [1048 rows x 26 columns]

# %% [markdown]
# ## Standarizing data (Transforming M to millons and k to thousands)

# %%
cleaning["Totalfollowers"]=cleaning["Totalfollowers"].str.replace(',','.')

# %%
cleaning["Totalfollowers"]=cleaning["Totalfollowers"].replace({"K":"*1e3", "M":"*1e6","k":"*1e3"}, regex=True).map(pd.eval).astype(int)

# %%
cleaning["Totalfollowers"].tail(30)
# Out:
# 1031     43400
# 1032     19000
# 1033    368600
# 1034    250800
# 1035     63800
# 1036    439600
# 1037    109000
# 1038     71900
# 1039    113000
# 1040    107000
# 1041     71100
# 1042     10900
# 1043     20200
# 1044    164000
# 1045     44600
# 1046    180000
# 1047    351000
# 1048    253000
# 1049    182000
# 1050    396000
# 1051    173000
# 1052    359000
# 1053    130000
# 1054    152000
# 1055    156000
# 1056     17900
# 1057     34300
# 1058     44600
# 1059     73700
# 1060     35700
# Name: Totalfollowers, dtype: int64

# %%
cleaning["followerspain"].tail(30)
# Out:
# 1031      43400
# 1032      19000
# 1033     169556
# 1034      62700
# 1035    Unknown
# 1036     197820
# 1037    Unknown
# 1038       3784
# 1039      41810
# 1040    Unknown
# 1041      22524
# 1042      10,9K
# 1043      20,2K
# 1044      60500
# 1045      22300
# 1046    Unknown
# 1047     112320
# 1048     112787
# 1049      90000
# 1050     130000
# 1051      85000
# 1052     175000
# 1053      63000
# 1054      75000
# 1055      78000
# 1056      17,9K
# 1057       8918
# 1058      22000
# 1059      40535
# 1060      24000
# Name: followerspain, dtype: object

# %%
cleaning["followerspain"] = cleaning["followerspain"].astype(str)

# %%
cleaning["followerspain"]=cleaning["followerspain"].str.replace(',','.')
cleaning["followerspain"]=cleaning["followerspain"].str.replace('unknown','0')
cleaning["followerspain"]=cleaning["followerspain"].str.replace('Unknown','0')

# %%
cleaning["followerspain"].tail(70)
# Out:
# 991     103.7K
# 992      29.6K
# 993      54.5K
# 994      51.5K
# 995      59.9K
#          ...
# 1056     17.9K
# 1057      8918
# 1058     22000
# 1059     40535
# 1060     24000
# Name: followerspain, Length: 70, dtype: object

# %%
cleaning["followerspain"]=cleaning["followerspain"].replace({"K":"*1e3", "M":"*1e6","k":"*1e3"}, regex=True).map(pd.eval).astype(int)

# %%
cleaning["followerspain"]
# Out:
# 0       12900000
# 1       13400000
# 2       11800000
# 3        3100000
# 4         915900
#           ...
# 1056       17900
# 1057        8918
# 1058       22000
# 1059       40535
# 1060       24000
# Name: followerspain, Length: 1048, dtype: int64

# %%
cleaning["followerspain"].tail(30)
# Out:
# 1031     43400
# 1032     19000
# 1033    169556
# 1034     62700
# 1035         0
# 1036    197820
# 1037         0
# 1038      3784
# 1039     41810
# 1040         0
# 1041     22524
# 1042     10900
# 1043     20200
# 1044     60500
# 1045     22300
# 1046         0
# 1047    112320
# 1048    112787
# 1049     90000
# 1050    130000
# 1051     85000
# 1052    175000
# 1053     63000
# 1054     75000
# 1055     78000
# 1056     17900
# 1057      8918
# 1058     22000
# 1059     40535
# 1060     24000
# Name: followerspain, dtype: int64

# %%
 cleaning["followerspain"]
# Out:
# 0       12900000
# 1       13400000
# 2       11800000
# 3        3100000
# 4         915900
#           ...
# 1056       17900
# 1057        8918
# 1058       22000
# 1059       40535
# 1060       24000
# Name: followerspain, Length: 1048, dtype: int64

# %%
null_columns=cleaning.columns[cleaning.isnull().any()]
cleaning[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
cleaning["authenticengament"] = cleaning["authenticengament"].astype(str)

# %%
cleaning["authenticengament"]=cleaning["authenticengament"].str.replace(',','.')

# %%
cleaning["authenticengament"]=cleaning["authenticengament"].replace({"K":"*1e3", "M":"*1e6","k":"*1e3"}, regex=True).map(pd.eval).astype(int)

# %%
cleaning["authenticengament"]
# Out:
# 0       3100000
# 1       2100000
# 2       2600000
# 3       2300000
# 4        540800
#          ...
# 1056          0
# 1057          0
# 1058          0
# 1059          0
# 1060          0
# Name: authenticengament, Length: 1048, dtype: int64

# %%
cleaning["%offemales"]=cleaning["%offemales"].str.replace(',','')
cleaning["%offemales"]=cleaning["%offemales"].str.replace(',,,,,,','')
cleaning["%offemales"]=cleaning["%offemales"].str.replace(',,,,,','')

# %%
cleaning.to_csv(r'/Users/marcpuyoliniesta/Desktop/Erasmus/cleaned.csv', index = False)

# %%
# Web-scrapping google images of all the influencers to import to tableau

# %%
cleaned=pd.read_excel('cleaned.xlsx')

# %%
import json
import selenium

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from IPython.display import Image
import datetime
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from tqdm import tqdm

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
s=Service(ChromeDriverManager().install())
 
# What you enter here will be searched for in
# Google Images
for i in tqdm(fashion['influencers']):
    query = i

    # Creating a webdriver instance
    driver = webdriver.Chrome(service=s)

    # Maximize the screen
    driver.maximize_window()

    # Open Google Images in the browser
    driver.get('https://images.google.com/')
    driver.find_element_by_xpath("//html/body/div[2]/div[2]/div[3]/span/div/div/div/div[3]/button[2]/div").click()
    
    time.sleep(10)

    # Finding the search box
    box = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')

    # Type the search query in the search box
    box.send_keys(query)

    # Pressing enter
    box.send_keys(Keys.ENTER)


    for i in range(1,2):

        try:

          # XPath of each image
            img = driver.find_element_by_xpath(
                '//*[@id="islrg"]/div[1]/div[' +
              str(i) + ']/a[1]/div[1]/img')

            # Enter the location of folder in which
            # the images will be saved
            img.screenshot('/Users/marcpuyoliniesta/Desktop/Erasmus' + 
                           query + ' (' + str(i) + ').png')
            # Each new screenshot will automatically
            # have its name updated

            # Just to avoid unwanted errors
            time.sleep(0.2)

        except:

            # if we can't find the XPath of an image,
            # we skip to the next image
            continue

    driver.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/160 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_2948/2442107315.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("//html/body/div[2]/div[2]/div[3]/span/div/div/div/div[3]/button[2]/div").click()
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_2948/2442107315.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   box = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_2948/2442107315.py:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   img = driver.find_element_by_xpath(
# 100%|█████████████████████████████████████████| 160/160 [45:52<00:00, 17.20s/it]
