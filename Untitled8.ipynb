# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd

# %%
def tiktok(x):
    tiktok=[]
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    time.sleep(5)
    for i in tqdm(x):
        driver.get("https://socialblade.com/search/search?query=" + i)
        time.sleep(7)
        try:
            content = driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div[1]').text
            tiktok.append(content)
        except:
            tiktok.append('Unknown')
    
    tiktok=pd.DataFrame(tiktok)
    return tiktok

# %%
tiktok(data['Account2'][991:999])

# %%
data=pd.read_excel('diezprimerostiktok4.xlsx')

# %%
data

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from IPython.display import Image
import datetime
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from tqdm import tqdm

# %%
def country(x):
    country=[]
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for i in tqdm(x):
        try:
            driver.get("https://starngage.com/app/es/influencers/" + i)
            time.sleep(11)
            try:
                content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[1]/div/div[2]/div[2]/div[2]/div').text
                country.append(content)
            except:
                country.append('Unknown')
        except:
            country.append('Unknown')
    country=pd.DataFrame(country)
    return country

# %%
data['age']=country(data['Account2'])

# %%
data.to_csv(r'/Users/marcpuyoliniesta/Desktop/Erasmus/data.csv', index = False)

# %%
data['age']

# %%
extraaccounts=pd.read_excel('Extraaccounts.xlsx')

# %%
instagramers=list(extraaccounts['Instagram account'])

# %%
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('ariviere\xa0','ariviere')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('belenhostalet\xa0','belenhostalet')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('goicoechea\xa0','goicoechea')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('gracyvillarreal\xa0','gracyvillarreal')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('lauraescanes\xa0','lauraescanes')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('mariafrubies\xa0','mariafrubies')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('mpombor\xa0','mpombor')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('riumbaumarta\xa0','riumbaumarta')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('sofia_suescun\xa0','sofia_suescun')
extraaccounts['Instagram account']=extraaccounts['Instagram account'].replace('teresaandresgonzalvo\xa0','teresaandresgonzalvo')

# %%
List=list(extraaccounts['Instagram account'])

# %%
List

# %%
extraaccounts['Instagram account'] = extraaccounts['Instagram account'].str.replace(' ', '')

# %%
extraaccounts

# %%
Etiquetados=[]
Etiquetados2=[]
def ultimostags(x):
    column_names = ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"]
    df2 = pd.DataFrame(columns = column_names)
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for a in tqdm(x):
        Etiquetados=[]
        driver.get("https://thesocialflame.com/influencer/" + a)
        time.sleep(3)
        try:
            content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
        except:
            try:
                content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text 
            except:
                content='Unknown'
        time.sleep(3)
        for i in content.split():
            if i.startswith("@"):
                Etiquetados.append(i)     
        Etiquetados2.append(Etiquetados[0:10])
    data = pd.DataFrame(Etiquetados2,columns= ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"])
    data.drop_duplicates()
    return data
data = pd.DataFrame(Etiquetados2,columns= ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"])
data.drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [Marcas1, Marcas2, Marcas3, Marcas4, Marcas5, Marcas6, Marcas7, Marcas8, Marcas9, Marcas10]
# Index: []

# %%
def females(x):
    females=[]
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for i in tqdm(x):
        driver.get("https://starngage.com/app/es/influencers/" + i)
        time.sleep(11)
        try:
            content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
            females.append(content)
        except:
            females.append('Unknown')
    
    females=pd.DataFrame(females)
    return females

# %%
def age(x):
    age=[]
    df2 = pd.DataFrame(columns = column_names)
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for i in tqdm(x):
        driver.get("https://starngage.com/app/es/influencers/" + i)
        time.sleep(8)
        try:
            content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[1]/div/div[2]/div[1]/div/p/span[2]').text
            age.append(content)
        except:
            age.append('Unknown')
    
    age=pd.DataFrame(age)
    return age

# %%
def country(x):
    country=[]
    df2 = pd.DataFrame(columns = column_names)
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for i in tqdm(x):
        driver.get("https://starngage.com/app/es/influencers/" + i)
        time.sleep(11)
        try:
            content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[1]/div/div[2]/div[2]/div[2]/div').text
            country.append(content)
        except:
            country.append('Unknown')
    
    country=pd.DataFrame(country)
    return country

# %%
def ultimostags(x):
    column_names = ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"]
    df2 = pd.DataFrame(columns = column_names)
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    Etiquetados=[]
    Etiquetados2=[]
    for a in tqdm(x):
        Etiquetados=[]
        driver.get("https://thesocialflame.com/influencer/" + a)
        time.sleep(3)
        try:
            content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
        except:
            try:
                content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text 
            except:
                content='Unknown'
        time.sleep(3)
        for i in content.split():
            if i.startswith("@"):
                Etiquetados.append(i)     
        Etiquetados2.append(Etiquetados[0:10])
    data = pd.DataFrame(Etiquetados2,columns= ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"])
    data.drop_duplicates()
    return data
data = pd.DataFrame(Etiquetados2,columns= ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"])
data.drop_duplicates()
# Out:
#                   Marcas1                 Marcas2                Marcas3  \
# 0            @carlomarnon                    None                   None
# 1    @biorepeelcl3_spain,         @doctorakarina,     @tuttibeauty.info,
# 2          @nareswimwear,           @laredoutees,          @thecolvinco,
# 3                    None                    None                   None
# 4    @juangarciaescudero,                    @hm,     @gaimoespadrilles,
# 5                    @hm,              @beirojas,          @aristocrazy,
# 6            @paolarajovc                    None                   None
# 7       @leftiesofficial,            @gigi_vives,        @memadridhotel,
# 8       @salvatore_plata,   @intimissimiofficial,         @amusesociety,
# 11         @browniespain,              @caudalie,      @tina___________,
# 13         @browniespain,               @subdued,       @arizonavintage,
# 14         @ronbrugal_es,  @delascuevasbarcelona,             @patrigoe,
# ...

# %%
import json
import selenium

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from IPython.display import Image
import datetime
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from tqdm import tqdm

# %%
def tiktok(x):
    tiktok=[]
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    time.sleep(5)
    for i in tqdm(x):
        driver.get("https://socialblade.com/search/search?query=" + i)
        time.sleep(7)
        try:
            content = driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div[1]').text
            tiktok.append(content)
        except:
            tiktok.append('Unknown')
    
    tiktok=pd.DataFrame(tiktok)
    return tiktok

# %%
tiktok(extraaccounts['Instagram account'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                    | 0/38 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_9794/2956910507.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div[1]').text
# 100%|███████████████████████████████████████████| 38/38 [05:18<00:00,  8.39s/it]
#           0
# 0   Unknown
# 1   Unknown
# 2   Unknown
# 3   Unknown
# 4   Unknown
# 5   Unknown
# 6   Unknown
# 7   Unknown
# 8   Unknown
# 9   Unknown
# 10  Unknown
# 11  Unknown
# 12  Unknown
# 13  Unknown
# 14  Unknown
# 15  Unknown
# 16  Unknown
# 17  Unknown
# 18  Unknown
# 19  Unknown
# 20  Unknown
# ...

# %%
tiktok(pau['insta account'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                    | 0/26 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_9794/2956910507.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div[1]').text
# 100%|███████████████████████████████████████████| 26/26 [04:52<00:00, 11.26s/it]
#           0
# 0   Unknown
# 1   Unknown
# 2   Unknown
# 3   Unknown
# 4   Unknown
# 5   Unknown
# 6   Unknown
# 7   Unknown
# 8   Unknown
# 9   Unknown
# 10  Unknown
# 11  Unknown
# 12  Unknown
# 13  Unknown
# 14  Unknown
# 15  Unknown
# 16  Unknown
# 17  Unknown
# 18  Unknown
# 19  Unknown
# 20  Unknown
# ...

# %%
data2=ultimostags(extraaccounts['Instagram account'])

# %%
data['%offemales']= females(extraaccounts['Instagram account'])

# %%
data

# %%
data2=data2.drop_duplicates().reset_index()

# %%
data2['%offemales']= data['%offemales']

# %%
data2

# %%
data2.to_csv(r'/Users/marcpuyoliniesta/Desktop/Erasmus/dataextraaccounts.csv', index = False)

# %%
pau=pd.read_excel('insta account.xlsx')

# %%
instagramers=list(pau['insta account'])

# %%
data3=ultimostags(pau['insta account'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                    | 0/26 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_9794/1095769663.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
#  12%|█████                                       | 3/26 [01:06<08:42, 22.73s/it]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_9794/1095769663.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text
# ...

# %%
data3
# Out:
#                   Marcas1                 Marcas2                Marcas3  \
# 0            @carlomarnon                    None                   None
# 1    @biorepeelcl3_spain,         @doctorakarina,     @tuttibeauty.info,
# 2          @nareswimwear,           @laredoutees,          @thecolvinco,
# 3                    None                    None                   None
# 4    @juangarciaescudero,                    @hm,     @gaimoespadrilles,
# 5                    @hm,              @beirojas,          @aristocrazy,
# 6            @paolarajovc                    None                   None
# 7       @leftiesofficial,            @gigi_vives,        @memadridhotel,
# 8       @salvatore_plata,   @intimissimiofficial,         @amusesociety,
# 9                    None                    None                   None
# 10                   None                    None                   None
# 11         @browniespain,              @caudalie,      @tina___________,
# ...

# %%
data3.to_csv(r'/Users/marcpuyoliniesta/Desktop/Erasmus/data3.csv', index = False)

# %%
data3['%offemales']= females(pau['insta account'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                    | 0/26 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_9794/938688012.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
# 100%|███████████████████████████████████████████| 26/26 [06:01<00:00, 13.92s/it]

# %%
data3['%offemales']
# Out:
# 0     Unknown
# 1      71.9 %
# 2      73.4 %
# 3     Unknown
# 4         0 %
# 5      66.8 %
# 6     Unknown
# 7         0 %
# 8      73.0 %
# 9     Unknown
# 10    Unknown
# 11        0 %
# 12    Unknown
# 13     71.1 %
# 14     66.6 %
# 15     77.7 %
# 16     70.5 %
# 17     71.0 %
# 18     64.2 %
# 19    Unknown
# 20     78.4 %
# 21     65.4 %
# 22    Unknown
# 23     72.4 %
# 24     70.2 %
# 25     76.3 %
# Name: %offemales, dtype: object

# %%
pau
# Out:
#     Unnamed: 0  Unnamed: 1     insta account
# 0          NaN         NaN       carlomarnon
# 1          NaN         NaN       sofiahamela
# 2          NaN         NaN            hralba
# 3          NaN         NaN       martacepeda
# 4          NaN         NaN       sheilaconde
# 5          NaN         NaN        paulabaset
# 6          NaN         NaN       paolarajovc
# 7          NaN         NaN         alibercan
# 8          NaN         NaN           coohuco
# 9          NaN         NaN        gemmapinto
# 10         NaN         NaN      tina________
# 11         NaN         NaN     carlotaweberm
# 12         NaN         NaN  melissavillareal
# 13         NaN         NaN      nuriablanco3
# 14         NaN         NaN          patrigoe
# 15         NaN         NaN    anamoyacalzado
# 16         NaN         NaN       luciaavfdez
# 17         NaN         NaN         jmuchelas
# 18         NaN         NaN        carlavicob
# 19         NaN         NaN  KATERINABEREZHNA
# ...
