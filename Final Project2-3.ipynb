# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import requests
import re
from bs4 import BeautifulSoup
from IPython.display import display
from IPython.core.display import display
from IPython.display import IFrame
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url= "https://hypeauditor.com/top-instagram-fashion-spain/"
results=requests.get(url)
soup = BeautifulSoup(results.content, 'html.parser')

# %%
results.text
# Out:
# '<!doctype html>\n<html data-n-head-ssr lang="en" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D">\n  <head >\n    <title>Top Fashion Influencers on Instagram in Spain | HypeAuditor Instagram Ranking</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1"><meta data-n-head="ssr" property="og:site_name" content="HypeAuditor.com"><meta data-n-head="ssr" property="og:type" content="website"><meta data-n-head="ssr" data-hid="og:image" property="og:image" content="https://hypeauditor.com/s/img/fb_share.png?1585074190.67"><meta data-n-head="ssr" data-hid="og:image:width" property="og:image:width" content="1200"><meta data-n-head="ssr" data-hid="og:image:height" property="og:image:height" content="628"><meta data-n-head="ssr" property="fb:app_id" content="709483869223213"><meta data-n-head="ssr" property="twitter:card" content="summary_large_image"><meta data-n-head="ssr" property="twitter:creator" content=
# ...

# %%
[item.text for item in soup.select(("td.td"))]
# Out:
# ['1',
#  'Georgina Rodríguez @georginagio',
#  'LifestyleFashionClothing & Outfits',
#  '36.2M',
#  '3M',
#  '2.3M',
#  '3.4M',
#  'Free Report',
#  '2',
#  'DORRA درة. @dorra_zarrouk',
#  'Cinema & Actors/actressesFashion',
#  '15.3M',
#  '1M',
#  '74.5K',
#  '100.7K',
#  'Free Report',
#  '3',
#  'Memes | Diy | Comedy | 5minute @tutorialsgallery',
#  'Art/ArtistsFashion',
#  '13.8M',
#  '570.2K',
#  '37.4K',
#  '55.5K',
#  'Free Report',
#  '4',
#  'Alessandra Ambrosio @alessandraambrosio',
#  'ModelingFashion',
#  '10.8M',
#  '511.9K',
#  '21.8K',
#  '33.8K',
#  'Preview',
#  '5',
#  'Valentino @maisonvalentino',
#  'Fashion',
#  '16.3M',
#  '660.4K',
#  '10.6K',
#  '15.1K',
#  'Preview',
#  '6',
#  'MARIA POMBO @mariapombo',
#  'FashionFamily',
#  '2.4M',
#  '1.6M',
#  '59.2K',
#  '101K',
#  'Preview',
#  '7',
#  'Michael Kors @michaelkors',
#  'FashionClothing & OutfitsShopping & Retail',
#  '17.1M',
#  '721.6K',
#  '8.7K',
#  '11.4K',
#  'Preview',
#  '8',
# ...

# %%
results = soup.find('td', class_='moh-rteTableFooterOddCol-6')

# %%
x=(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))

# %%
def influencers(x):
    url= x
    results=requests.get(url)
    soup = BeautifulSoup(results.content, 'html.parser')
    title=[]
    Totalfollowers = [item.text for item in soup.select('.td:nth-of-type(4):not([id])')]
    followerspain = [item.text for item in soup.select('.td:nth-of-type(5):not([id])')]
    authenticengament=[item.text for item in soup.select('.td:nth-of-type(6):not([id])')]
    Engagementavg=[item.text for item in soup.select('.td:nth-of-type(7):not([id])')]
    len_songs=len(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
    account2=[]
    links=[]
    for i in range(len_songs):
        title.append(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
        tatd=str(title)
        tatd=tatd.replace('<td class="td" data-v-1c693a69="" style="width:280px;min-width:280px;max-width:280px;">','')
        tatd=tatd.split(',')
        df = pd.DataFrame (tatd, columns = ['column_name'])
        df[['Name','Account']] = df.column_name.str.split("@",expand=True,)
        df=df.drop(columns=['column_name'])
        df = df.drop_duplicates(subset='Name', keep="first")
        df = df.drop_duplicates(subset='Account', keep="first")
        df.reset_index()
        followers = pd.Series(Totalfollowers)
        followerspain=pd.Series(followerspain)
        df['Totalfollowers'] = followers
        df['followerspain']=followerspain
        authenticengament = pd.Series(authenticengament)
        df['authenticengament']=authenticengament.values
        account=list(df['Account'])
        for i in account:
            account=i.replace('</td>','')
            account=account.replace(']]','')
            account2.append(account)
        df['Account2']= account2
        for i in account2: 
            links.append('https://www.instagram.com/'+i+'/?hl=es')
        df['links']=links

        return df

# %%
def fitnessspa(x):
    url= x
    results=requests.get(url)
    soup = BeautifulSoup(results.content, 'html.parser')
    title=[]
    Totalfollowers = [item.text for item in soup.select('.td:nth-of-type(4):not([id])')]
    followerspain = [item.text for item in soup.select('.td:nth-of-type(5):not([id])')]
    authenticengament=[item.text for item in soup.select('.td:nth-of-type(6):not([id])')]
    Engagementavg=[item.text for item in soup.select('.td:nth-of-type(7):not([id])')]
    len_songs=len(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
    account2=[]
    links=[]
    for i in range(len_songs):
        title.append(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
        tatd=str(title)
        tatd=tatd.replace('<td class="td" data-v-1c693a69="" style="width:280px;min-width:280px;max-width:280px;">','')
        tatd=tatd.replace('🍑Salud, Deporte &amp','🍑Salud Deporte &amp')
        tatd=tatd.split(',')
        df = pd.DataFrame (tatd, columns = ['column_name'])
        df[['Name','Account']] = df.column_name.str.split("@",expand=True,)
        df=df.drop(columns=['column_name'])
        df = df.drop_duplicates(subset='Name', keep="first")
        df = df.drop_duplicates(subset='Account', keep="first")
        df.reset_index()
        followers = pd.Series(Totalfollowers)
        followerspain=pd.Series(followerspain)
        df['Totalfollowers'] = followers
        df['followerspain']=followerspain
        authenticengament = pd.Series(authenticengament)
        df['authenticengament']=authenticengament.values
        account=list(df['Account'])
        for i in account:
            account=i.replace('</td>','')
            account2.append(account)
        df['Account2']= account2
        for i in account2: 
            links.append('https://www.instagram.com/'+i+'/?hl=es')
        df['links']=links

        return df

# %%
def fitnesita(x):
    url= x
    results=requests.get(url)
    soup = BeautifulSoup(results.content, 'html.parser')
    title=[]
    Totalfollowers = [item.text for item in soup.select('.td:nth-of-type(4):not([id])')]
    followerspain = [item.text for item in soup.select('.td:nth-of-type(5):not([id])')]
    authenticengament=[item.text for item in soup.select('.td:nth-of-type(6):not([id])')]
    Engagementavg=[item.text for item in soup.select('.td:nth-of-type(7):not([id])')]
    len_songs=len(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
    account2=[]
    links=[]
    for i in range(len_songs):
        title.append(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
        tatd=str(title)
        tatd=tatd.replace('<td class="td" data-v-1c693a69="" style="width:280px;min-width:280px;max-width:280px;">','')
        tatd=tatd.replace('🍑Salud, Deporte &amp','🍑Salud Deporte &amp')
        tatd=tatd.split(',')
        df = pd.DataFrame (tatd, columns = ['column_name'])
        df[['Name','Account']] = df.column_name.str.split("@",expand=True,)
        df=df.drop(columns=['column_name'])
        df.reset_index()
        followers = pd.Series(Totalfollowers)
        followerspain=pd.Series(followerspain)
        df['Totalfollowers'] = followers
        df['followerspain']=followerspain
        authenticengament = pd.Series(authenticengament)
        df['authenticengament']=authenticengament.values
        account=list(df['Account'])
        for i in account:
            account=i.replace('</td>','')
            account2.append(account)
        df['Account2']= account2
        for i in account2: 
            links.append('https://www.instagram.com/'+i+'/?hl=es')
        df['links']=links

        return df

# %%
def BadBunny(x):
    url= x
    results=requests.get(url)
    soup = BeautifulSoup(results.content, 'html.parser')
    title=[]
    Totalfollowers = [item.text for item in soup.select('.td:nth-of-type(4):not([id])')]
    followerspain = [item.text for item in soup.select('.td:nth-of-type(5):not([id])')]
    authenticengament=[item.text for item in soup.select('.td:nth-of-type(6):not([id])')]
    Engagementavg=[item.text for item in soup.select('.td:nth-of-type(7):not([id])')]
    len_songs=len(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
    account2=[]
    links=[]
    for i in range(len_songs):
        title.append(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
        tatd=str(title)
        tatd=tatd.replace('<td class="td" data-v-1c693a69="" style="width:280px;min-width:280px;max-width:280px;">','')
        tatd=tatd.replace('@ozutochi 🔜 #TemporadaDelOzo @ozuna</td>','ozutochi 🔜 #TemporadaDelOzo @ozuna</td>')
        tatd=tatd.split(',')
        df = pd.DataFrame (tatd, columns = ['column_name'])
        df[['Name','Account']] = df.column_name.str.split("@",expand=True,)
        df=df.drop(columns=['column_name'])
        df = df.drop_duplicates(subset='Name', keep="first")
        df = df.drop_duplicates(subset='Account', keep="first")
        df.reset_index()
        followers = pd.Series(Totalfollowers)
        followerspain=pd.Series(followerspain)
        df['Totalfollowers'] = followers
        df['followerspain']=followerspain
        authenticengament = pd.Series(authenticengament)
        df['authenticengament']=authenticengament.values
        account=list(df['Account'])
        for i in account:
            account=i.replace('</td>','')
            account2.append(account)
        df['Account2']= account2
        for i in account2: 
            links.append('https://www.instagram.com/'+i+'/?hl=es')
        df['links']=links

        return df

# %%
def problemasconcomas(x):
    url= x
    results=requests.get(url)
    soup = BeautifulSoup(results.content, 'html.parser')
    title=[]
    Totalfollowers = [item.text for item in soup.select('.td:nth-of-type(4):not([id])')]
    followerspain = [item.text for item in soup.select('.td:nth-of-type(5):not([id])')]
    authenticengament=[item.text for item in soup.select('.td:nth-of-type(6):not([id])')]
    Engagementavg=[item.text for item in soup.select('.td:nth-of-type(7):not([id])')]
    len_songs=len(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
    account2=[]
    links=[]
    for i in range(len_songs):
        title.append(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
        tatd=str(title)
        tatd=tatd.replace('<td class="td" data-v-1c693a69="" style="width:280px;min-width:280px;max-width:280px;">','')
        tatd=tatd.replace(' K-tuin, tiendas Apple @ktuin_apple</td>', ' K-tuin tiendas Apple @ktuin_apple</td>')
        tatd=tatd.split(',')
        df = pd.DataFrame (tatd, columns = ['column_name'])
        df[['Name','Account']] = df.column_name.str.split("@",expand=True,)
        df=df.drop(columns=['column_name'])
        df = df.drop_duplicates(subset='Name', keep="first")
        df = df.drop_duplicates(subset='Account', keep="first")
        df.reset_index()
        followers = pd.Series(Totalfollowers)
        followerspain=pd.Series(followerspain)
        df['Totalfollowers'] = followers
        df['followerspain']=followerspain
        authenticengament = pd.Series(authenticengament)
        df['authenticengament']=authenticengament.values
        account=list(df['Account'])
        for i in account:
            account=i.replace('</td>','')
            account2.append(account)
        df['Account2']= account2
        for i in account2: 
            links.append('https://www.instagram.com/'+i+'/?hl=es')
        df['links']=links

        return df

# %%
def artistasitalia(x):
    url= x
    results=requests.get(url)
    soup = BeautifulSoup(results.content, 'html.parser')
    title=[]
    Totalfollowers = [item.text for item in soup.select('.td:nth-of-type(4):not([id])')]
    followerspain = [item.text for item in soup.select('.td:nth-of-type(5):not([id])')]
    authenticengament=[item.text for item in soup.select('.td:nth-of-type(6):not([id])')]
    Engagementavg=[item.text for item in soup.select('.td:nth-of-type(7):not([id])')]
    len_songs=len(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
    account2=[]
    links=[]
    for i in range(len_songs):
        title.append(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
        tatd=str(title)
        tatd=tatd.replace('<td class="td" data-v-1c693a69="" style="width:280px;min-width:280px;max-width:280px;">','')
        tatd=tatd.replace('Aldo, Giovanni e Giacomo','Aldo Giovanni e Giacomo')
        tatd=tatd.split(',')
        df = pd.DataFrame (tatd, columns = ['column_name'])
        df[['Name','Account']] = df.column_name.str.split("@",expand=True,)
        df=df.drop(columns=['column_name'])
        df = df.drop_duplicates(subset='Name', keep="first")
        df = df.drop_duplicates(subset='Account', keep="first")
        df.reset_index()
        followers = pd.Series(Totalfollowers)
        followerspain=pd.Series(followerspain)
        df['Totalfollowers'] = followers
        df['followerspain']=followerspain
        authenticengament = pd.Series(authenticengament)
        df['authenticengament']=authenticengament.values
        account=list(df['Account'])
        for i in account:
            account=i.replace('</td>','')
            account2.append(account)
        df['Account2']= account2
        for i in account2: 
            links.append('https://www.instagram.com/'+i+'/?hl=es')
        df['links']=links

        return df

# %%
def humoristasitalia(x):
    url= x
    results=requests.get(url)
    soup = BeautifulSoup(results.content, 'html.parser')
    title=[]
    Totalfollowers = [item.text for item in soup.select('.td:nth-of-type(4):not([id])')]
    followerspain = [item.text for item in soup.select('.td:nth-of-type(5):not([id])')]
    authenticengament=[item.text for item in soup.select('.td:nth-of-type(6):not([id])')]
    Engagementavg=[item.text for item in soup.select('.td:nth-of-type(7):not([id])')]
    len_songs=len(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
    account2=[]
    links=[]
    for i in range(len_songs):
        title.append(soup.select('td[style="width:280px;min-width:280px;max-width:280px;"]'))
        tatd=str(title)
        tatd=tatd.replace('<td class="td" data-v-1c693a69="" style="width:280px;min-width:280px;max-width:280px;">','')
        tatd=tatd.replace('Aldo, Giovanni e Giacomo','Aldo Giovanni e Giacomo')
        tatd=tatd.replace('NASCE, CRESCE, IGNORA®','NASCE CRESCE IGNORA®')
        tatd=tatd.split(',')
        df = pd.DataFrame (tatd, columns = ['column_name'])
        df[['Name','Account']] = df.column_name.str.split("@",expand=True,)
        df=df.drop(columns=['column_name'])
        df = df.drop_duplicates(subset='Name', keep="first")
        df = df.drop_duplicates(subset='Account', keep="first")
        df.reset_index()
        followers = pd.Series(Totalfollowers)
        followerspain=pd.Series(followerspain)
        df['Totalfollowers'] = followers
        df['followerspain']=followerspain
        authenticengament = pd.Series(authenticengament)
        df['authenticengament']=authenticengament.values
        account=list(df['Account'])
        for i in account:
            account=i.replace('</td>','')
            account=account.replace(']]','')
            account2.append(account)
        df['Account2']= account2
        for i in account2: 
            links.append('https://www.instagram.com/'+i+'/?hl=es')
        df['links']=links

        return df

# %%
countries= ['spain','italy']
for i in countries: 
    dataFashionspa=influencers('https://hypeauditor.com/top-instagram-fashion-'+countries[0]+'/')
    dataFashionitl=influencers('https://hypeauditor.com/top-instagram-fashion-'+countries[1]+'/')
    dataFashionspa['Category']= 'Fashion'
    dataFashionitl['Category']= 'Fashion'
    dataFashionspa['Country']= countries[0]
    dataFashionitl['Country']= countries[1]
fashion=pd.concat([dataFashionitl,dataFashionspa],axis=0).reset_index()
fashion['Type']=Webscrapping(fashion['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   notnow = driver.find_element_by_xpath("//button[contains(text(), 'Permitir solo cookies necesarias')]").click()
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username=driver.find_element_by_css_selector("input[name='username']")
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
def ultimostags(x):
    column_names = ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"]
    df2 = pd.DataFrame(columns = column_names)
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    Etiquetados=[]
    Etiquetados2=[]
    for a in tqdm(x):
        Etiquetados=[]
        driver.get("https://thesocialflame.com/influencer/" + a)
        time.sleep(3)
        try:
            content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
        except:
            try:
                content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text 
            except:
                content='Unknown'
        time.sleep(3)
        for i in content.split():
            if i.startswith("@"):
                Etiquetados.append(i)     
        Etiquetados2.append(Etiquetados[0:10])
    data = pd.DataFrame(Etiquetados2,columns= ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"])
    data.drop_duplicates()
    return data
data = pd.DataFrame(Etiquetados2,columns= ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"])
data.drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [Marcas1, Marcas2, Marcas3, Marcas4, Marcas5, Marcas6, Marcas7, Marcas8, Marcas9, Marcas10]
# Index: []

# %%
data=ultimostags(fashion['Account2'][80:85])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                     | 0/5 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
#  60%|███████████████████████████                  | 3/5 [01:28<00:59, 29.52s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/1542029342.py in <module>
# ----> 1 data=ultimostags(fashion['Account2'][80:85])
#
# ...

# %%
Fashion=pd.concat([fashion, data], axis=1)

# %%
Fashion['%offemales']= females(Fashion['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2642957948.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
# 100%|█████████████████████████████████████████| 100/100 [24:37<00:00, 14.78s/it]

# %%
Fashion
# Out:
#     index                   Name                 Account Totalfollowers  \
# 0       0             [[Kendall       kendalljenner</td>         223.4M
# 1       1        Kim Kardashian       kimkardashian</td>         291.7M
# 2       2              Beyoncé             beyonce</td>         242.6M
# 3       3   Georgina Rodríguez         georginagio</td>          36.2M
# 4       4        Barbara Palvin   realbarbarapalvin</td>          17.4M
# ..    ...                    ...                     ...            ...
# 95     45              Roneo 👑🐊        roneooficial</td>         135.7K
# 96     46     CAMILLE by Silvia         camillebys_</td>         199.4K
# 97     47             Marianela     marilynsclosetb</td>         201.5K
# 98     48                               gianinetto_</td>         123.2K
# 99     49          JOSE RUEDA 🌹        josiito.12</td>]]           132K
#
#    followerspain authenticengament           Account2  \
# ...

# %%
countries= ['spain','italy']
for i in countries: 
    datasportswithballspa=influencers('https://hypeauditor.com/top-instagram-sports-with-a-ball-'+countries[0]+'/')
    datasportswithballita=influencers('https://hypeauditor.com/top-instagram-sports-with-a-ball-'+countries[1]+'/')
    datasportswithballspa['Category']= 'Sportballers'
    datasportswithballita['Category']= 'Sportballers'
    datasportswithballspa['Country']= countries[0]
    datasportswithballita['Country']= countries[1]
datasportswithball=pd.concat([datasportswithballspa,datasportswithballita],axis=0).reset_index()
datasportswithball['Type']=Webscrapping(datasportswithball['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   notnow = driver.find_element_by_xpath("//button[contains(text(), 'Permitir solo cookies necesarias')]").click()
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username=driver.find_element_by_css_selector("input[name='username']")
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
datas=ultimostags(datasportswithball['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
#  82%|██████████████████████████████████▍       | 82/100 [25:46<07:32, 25.14s/it]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text
# ...

# %%
datas
# Out:
#              Marcas1             Marcas2            Marcas3           Marcas4  \
# 0      @insparya_es,      @visitmadeira,      @piersmorgan,   @sixpad_europe,
# 1   @adidasfootball,     @themessistore,       @thg.agency,      @jacobandco,
# 2        @gilcebola,  @dieselfragrances,    @gabrielmedina,            @nike,
# 3              @psg,      @nikefootball,         @neymarjr,   @gabrielmedina,
# 4           @vinijr,        @realmadrid,      @sergioramos,          @brahim,
# ..               ...                 ...                ...               ...
# 95   @lacazettealex,           @arsenal,        @rangersfc,  @alvaronegredo9,
# 96  @stefanosensi12,       @mrmancini10,     @paologhiglio,       @berardi25,
# 97   @antogriezmann,             @inter,              @433,  @germanpezzella,
# 98       @chelseafc,      @tammyabraham,  @championsleague,         @ebay_uk,
# 99   @driesmertens]]                None               None              None
#
# ...

# %%
Sportswithball=pd.concat([datasportswithball, datas], axis=1)

# %%
Sportswithball
# Out:
#     index                            Name                Account  \
# 0       0            [[Cristiano Ronaldo          cristiano</td>
# 1       1                      Leo Messi           leomessi</td>
# 2       2                          NJ 🇧🇷           neymarjr</td>
# 3       3                 Kylian Mbappé           k.mbappe</td>
# 4       4               Real Madrid C.F.         realmadrid</td>
# ..    ...                             ...                    ...
# 95     45             UEFA Europa League       europaleague</td>
# 96     46   Nazionale Italiana di Calcio            azzurri</td>
# 97     47               CALCIATORIBRUTTI   calciatoribrutti</td>
# 98     48                Jorginho Frello     jorginhofrello</td>
# 99     49                  Dries Mertens     driesmertens</td>]]
#
#    Totalfollowers followerspain authenticengament          Account2  \
# 0          411.6M         18.3M              5.8M         cristiano
# ...

# %%
Sportswithball['%offemales']= females(Sportswithball['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2394731624.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
# 100%|█████████████████████████████████████████| 100/100 [24:06<00:00, 14.47s/it]

# %%
countries= ['spain','italy']
for i in countries: 
    fitnessspa=fitnesita('https://hypeauditor.com/top-instagram-fitness-gym-'+countries[0]+'/')
    fitnessitl=fitnesita('https://hypeauditor.com/top-instagram-fitness-gym-'+countries[1]+'/')
    fitnessspa['Category']= 'Fitness'
    fitnessitl['Category']= 'Fitness'
    fitnessspa['Country']= countries[0]
    fitnessitl['Country']= countries[1]   
fitness=pd.concat([fitnessspa,fitnessitl],axis=0).reset_index()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   notnow = driver.find_element_by_xpath("//button[contains(text(), 'Permitir solo cookies necesarias')]").click()
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username=driver.find_element_by_css_selector("input[name='username']")
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/384722463.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
dataf=ultimostags(fitness['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
#  16%|██████▋                                   | 16/100 [06:36<35:09, 25.11s/it]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text
# ...

# %%
Fitness=pd.concat([fitness, dataf], axis=1)

# %%
Fitness['%offemales']= females(Fitness['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2394731624.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
# 100%|█████████████████████████████████████████| 100/100 [29:55<00:00, 17.95s/it]

# %%
Fitness
# Out:
#     index                             Name                          Account  \
# 0       0     [[Mohamed Emam • محمد إمام                  mohamedemam</td>
# 1       1                  Michelle Lewin               michelle_lewin</td>
# 2       2                     Dani Ospina              daniela_ospina5</td>
# 3       3               Gym Virtual✌🏻✊🏻🖐🏻               gymvirtual_com</td>
# 4       4          Sergio Peinado Trainer         sergiopeinadotrainer</td>
# ..    ...                              ...                              ...
# 95     45                     Emily👱🏻‍♀️😈                     memly_02</td>
# 96     46                   Manuel Caruso   manuel_caruso_calisthenics</td>
# 97     47                  Lucas Peracchi                lucasperacchi</td>
# 98     48   💖Lara De Santis💖(Oana Tudose)        laradesantis_official</td>
# 99     49                    Matteo Piano                     teuzzo</td>]]
#
# ...

# %%
Fashion=Fashion.drop(['Type'], axis=1)

# %%
Sportswithball=Sportswithball.drop(['Type'], axis=1)

# %%
tresprimeros=pd.concat([Fashion,Sportswithball,Fitness],axis=0).reset_index()

# %%
tresprimeros.to_csv(r'/Users/marcpuyoliniesta/Desktop/Erasmus/tresprimeros.csv', index = False)

# %%
countries= ['spain','italy']
for i in countries: 
    beautyspa=influencers('https://hypeauditor.com/top-instagram-beauty-'+countries[0]+'/')
    beautyitl=influencers('https://hypeauditor.com/top-instagram-beauty-'+countries[1]+'/')
    beautyspa['Category']= 'Beauty'
    beautyitl['Category']= 'Beauty'
    beautyspa['Country']= countries[0]
    beautyitl['Country']= countries[1]
beauty=pd.concat([beautyspa,beautyitl],axis=0).reset_index()

# %%
datab=ultimostags(beauty['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
# 100%|█████████████████████████████████████████| 100/100 [37:50<00:00, 22.70s/it]

# %%
Beauty=pd.concat([beauty, datab], axis=1)

# %%
Beauty['%offemales']= females(Beauty['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2394731624.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
# 100%|█████████████████████████████████████████| 100/100 [25:41<00:00, 15.42s/it]

# %%
Beauty
# Out:
#     index                       Name                Account Totalfollowers  \
# 0       0             [[Addison Rae        addisonraee</td>          40.4M
# 1       1                     avani              avani</td>          18.7M
# 2       2          Luisa Fernanda W     luisafernandaw</td>          16.8M
# 3       3   Paula Galindo | Pautips            pautips</td>           8.2M
# 4       4      KIKO Milano Official         kikomilano</td>           4.9M
# ..    ...                        ...                    ...            ...
# 95     45             Giulia Latini         bionditudo</td>         783.2K
# 96     46      Maria Teresa Buccino       maritbuccino</td>         801.9K
# 97     47                  Michelle    michelleputtini</td>         185.6K
# 98     48            Katia Pedrotti          misskatia</td>         522.4K
# 99     49           Martina Luchena   martinaluchena</td>]]         711.3K
#
#    followerspain authenticengament          Account2  \
# ...

# %%
countries= ['spain','italy']
for i in countries:
    Humorspa=influencers('https://hypeauditor.com/top-instagram-humor-fun-happiness-'+countries[0]+'/')
    Humoritl=humoristasitalia('https://hypeauditor.com/top-instagram-humor-fun-happiness-'+countries[1]+'/')
    Humorspa['Category']='Humor'
    Humoritl['Category']='Humor'
    Humorspa['Country']= countries[0]
    Humoritl['Country']= countries[1]
Humor=pd.concat([Humorspa,Humoritl],axis=0).reset_index()

# %%
datah=ultimostags(Humor['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
#  67%|████████████████████████████▏             | 67/100 [24:59<12:09, 22.12s/it]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2689018351.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text
# ...

# %%
Humor=pd.concat([Humor, datah], axis=1)

# %%
Humor['%offemales']= females(Humor['Account2'])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2394731624.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
# 100%|█████████████████████████████████████████| 100/100 [23:53<00:00, 14.34s/it]

# %%
Humor
# Out:
#     index                         Name               Account Totalfollowers  \
# 0       0         [[Luisillo El Pillo   luisitocomunica</td>          31.5M
# 1       1            Cultura Positiva   culturapositiva</td>           9.5M
# 2       2      Las aventuras de Nacho           nachter</td>           2.9M
# 3       3    Marko &gt; Comedia Viral             marko</td>             8M
# 4       4   barzan koohi | برزان کوهی    barzanofficial</td>           1.2M
# ..    ...                          ...                   ...            ...
# 95     45                Giulio Mosca       ilbaffogram</td>         578.7K
# 96     46             Oroscopo Social      onlyoroscopo</td>         721.5K
# 97     47     Aldo Giovanni e Giacomo     agg_ufficiale</td>           749K
# 98     48      𝐈𝐯𝐚𝐧𝐚 𝐌𝐫𝐚𝐳𝐨𝐯𝐚 𝐎𝐟𝐟𝐢𝐜𝐢𝐚𝐥     ivana_mrazova</td>             1M
# 99     49                      Lercio       lercio.it</td>]]         801.8K
#
#    followerspain authenticengament         Account2  \
# ...

# %%
cincoprimeros=pd.concat([Fashion,Sportswithball,Fitness,Beauty,Humor],axis=0).reset_index()

# %%
cincoprimeros.to_csv(r'/Users/marcpuyoliniesta/Desktop/Erasmus/cincoprimeros.csv', index = False)

# %%
countries= ['spain','italy']
for i in countries:
    marketingspa=influencers('https://hypeauditor.com/top-instagram-management-marketing-'+countries[0]+'/')
    marketingitl=influencers('https://hypeauditor.com/top-instagram-management-marketing-'+countries[1]+'/')
    marketingspa['Category']='marketing'
    marketingitl['Category']='marketing'
    marketingspa['Country']= countries[0]
    marketingitl['Country']= countries[1]
Marketing=pd.concat([marketingspa,marketingitl],axis=0).reset_index()

# %%
Marketing=pd.concat([Marketing, datam], axis=1)

# %%
Marketing['%offemales']= females(Marketing['Account2'])

# %%
countries= ['spain','italy']
for i in countries:
    kidsspa=influencers('https://hypeauditor.com/top-instagram-kids-toys-'+countries[0]+'/')
    kidsitl=influencers('https://hypeauditor.com/top-instagram-kids-toys-'+countries[1]+'/')
    kidsspa['Category']='Kids'
    kidsitl['Category']='Kids'
    kidsspa['Country']= countries[0]
    kidsitl['Country']= countries[1]
Kids=pd.concat([kidsspa,kidsitl],axis=0).reset_index()

# %%
datak=ultimostags(Kids['Account2'])

# %%
Kids=pd.concat([Kids, datam], axis=1)

# %%
Kids['%offemales']= females(Kids['Account2'])

# %%
countries= ['spain','italy']
for i in countries:
    Coachesspa=influencers('https://hypeauditor.com/top-instagram-trainers-coaches-'+countries[0]+'/')
    Coachesitl=influencers('https://hypeauditor.com/top-instagram-trainers-coaches-'+countries[1]+'/') 
    Coachesspa['Category']='Coach'
    Coachesitl['Category']='Coach'
    Coachesspa['Country']= countries[0]
    Coachesitl['Country']= countries[1]
Coaches=pd.concat([Coachesspa,Coachesitl],axis=0).reset_index()

# %%
datac=ultimostags(Coaches['Account2'])

# %%
Coaches=pd.concat([Coaches, datac], axis=1)

# %%
Coaches['%offemales']= females(Coaches['Account2'])

# %%
countries= ['spain','italy']
for i in countries:
    Musicspa=BadBunny('https://hypeauditor.com/es/top-instagram-music-'+countries[0]+'/')
    Musicitl=influencers('https://hypeauditor.com/es/top-instagram-music-'+countries[1]+'/')
    Musicspa['Country']= countries[0]
    Musicitl['Country']= countries[1]
    Musicspa['Category']='Music'
    Musicitl['Category']='Music'
Music=pd.concat([Musicspa,Musicitl],axis=0).reset_index()

# %%
dataM=ultimostags(Music['Account2'])

# %%
Music=pd.concat([Music, dataM], axis=1)

# %%
Music['%offemales']= females(Music['Account2'])

# %%
countries= ['spain','italy']
for i in countries:
    Artistasspa=influencers('https://hypeauditor.com/es/top-instagram-art-artists-'+countries[0]+'/')
    Artistasitl=artistasitalia('https://hypeauditor.com/es/top-instagram-art-artists-'+countries[1]+'/')
    Artistasspa['Category']='Artistas'
    Artistasitl['Category']='Artistas'
    Artistasspa['Country']= countries[0]
    Artistasitl['Country']= countries[1]
Artists=pd.concat([Artistasspa,Artistasitl],axis=0).reset_index()

# %%
dataA=ultimostags(Artists['Account2'])

# %%
Artists=pd.concat([Artists, dataA], axis=1)

# %%
Artists['%offemales']= females(Artists['Account2'])

# %%
countries= ['spain','italy']
for i in countries:
    Tecnologiaspa=influencers('https://hypeauditor.com/es/top-instagram-computers-gadgets-'+countries[0]+'/')
    Tecnologiaitl=influencers('https://hypeauditor.com/es/top-instagram-computers-gadgets-'+countries[1]+'/')
    Tecnologiaspa['Category']='Tecnología'
    Tecnologiaitl['Category']='Tecnología'
    Tecnologiaspa['Country']=countries[0]
    Tecnologiaitl['Country']=countries[1]
Technology=pd.concat([Tecnologiaspa,Tecnologiaitl],axis=0).reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2871726285.py in <module>
#       1 countries= ['spain','italy']
#       2 for i in countries:
# ----> 3     Tecnologiaspa=influencers('https://hypeauditor.com/es/top-instagram-computers-gadgets-'+countries[0]+'/')
#       4     Tecnologiaitl=influencers('https://hypeauditor.com/es/top-instagram-computers-gadgets-'+countries[1]+'/')
#       5     Tecnologiaspa['Category']='Tecnología'
#
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/1558208695.py in influencers(x)
#      27         df['followerspain']=followerspain
#      28         authenticengament = pd.Series(authenticengament)
# ---> 29         df['authenticengament']=authenticengament.values
#      30         account=list(df['Account'])
#      31         for i in account:
#
# ...

# %%
Cuentas=pd.concat([fashion,datasportswithball,fitness,beauty,Humor,Marketing,Kids,Coaches,Music,Artists],axis=0).reset_index()

# %%
Cuentas.tail(50)
# Out:
#      level_0  index                              Name  \
# 950       50      0             [[Stefano De Martino
# 951       51      1             Sascha Burci - Anima
# 952       52      2                   Elena d'Amario
# 953       53      3                          Andreas
# 954       54      4                  Luciano Ligabue
# 955       55      5                             JAGO
# 956       56      6                    Drusilla Foer
# 957       57      7                Lorella Cuccarini
# 958       58      8                     Giulio Mosca
# 959       59      9                 Emanuele Picozzi
# 960       60     10          Aldo Giovanni e Giacomo
# 961       61     11             Alessandra Celentano
# 962       62     12                    Roberto Bolle
# 963       63     13              Lasse L. Matberg 🇳🇴
# 964       64     14                   Simone Nolasco
# 965       65     15                  Tesori Italiani
# 966       66     16          Pop Culture in Pictures
# ...

# %%
Cuentas.to_csv(r'/Users/marcpuyoliniesta/Desktocp/Erasmus\Finalproject.csv', index = False)

# %%
Cuentas['Account'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Account, Length: 1000, dtype: bool

# %%
import json
import selenium

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from IPython.display import Image
import datetime
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from tqdm import tqdm

# %%
dataFashionspa
# Out:
#                                 Name                   Account Totalfollowers  \
# 0             [[Georgina Rodríguez           georginagio</td>          36.2M
# 1                        DORRA درة.         dorra_zarrouk</td>          15.3M
# 2    Memes | Diy | Comedy | 5minute      tutorialsgallery</td>          13.8M
# 3               Alessandra Ambrosio    alessandraambrosio</td>          10.8M
# 4                         Valentino       maisonvalentino</td>          16.3M
# 5                       MARIA POMBO            mariapombo</td>           2.4M
# 6                      Michael Kors           michaelkors</td>          17.1M
# 7                     Aida Domenech              dulceida</td>             3M
# 8                   𝘼𝙡𝙚𝙭 𝙈𝙖𝙣𝙙𝙤𝙣 𝙍𝙚𝙮        alextopdancerr</td>           1.3M
# 9                  ᴘᴀᴜʟᴀ ᴇᴄʜᴇᴠᴀʀʀɪᴀ              pau_eche</td>           3.6M
# 10                  CristiPedroche🦋        cristipedroche</td>             3M
# ...

# %%
def Webscrapping(x):
    Modelo2=[]
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    driver.get("https://www.instagram.com/")
    time.sleep(10)
    notnow = driver.find_element_by_xpath("//button[contains(text(), 'Permitir solo cookies necesarias')]").click()
    username=driver.find_element_by_css_selector("input[name='username']")
    password=driver.find_element_by_css_selector("input[name='password']")
    username.clear()
    password.clear()
    username.send_keys("perico.palote72")
    time.sleep(15)
    password.send_keys("Manolo72.")
    time.sleep(10)
    login = driver.find_element_by_css_selector("button[type='submit']").click()
    #save your login info?
    time.sleep(10)
    notnow = driver.find_element_by_xpath("//button[contains(text(), 'Ahora no')]").click()
    #turn on notif
    time.sleep(10)
    notnow2 = driver.find_element_by_xpath("//button[contains(text(), 'Ahora no')]").click()
    #searchbox
    time.sleep(10)
    for i in tqdm(x):
        searchbox=driver.find_element_by_css_selector("input[placeholder='Busca']")
        searchbox.clear()
        searchbox.send_keys(i)
        time.sleep(6)
        searchbox.send_keys(Keys.ENTER)
        time.sleep(6)
        searchbox.send_keys(Keys.ENTER)
        time.sleep(6)
        try:
            content = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/header/section/div[2]/div[1]/div').text
            Modelo2.append(content)
        except:
            Modelo2.append('Unknown')
    
    Modelo=pd.DataFrame(Modelo2)
    return Modelo

# %%
Webscrapping()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/2962993297.py in <module>
# ----> 1 Webscrapping()
#
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/3707470542.py in Webscrapping()
#       4     driver = webdriver.Chrome(service=s)
#       5     driver.get("https://www.instagram.com/")
# ----> 6     time.sleep(10)
#       7     notnow = driver.find_element_by_xpath("//button[contains(text(), 'Permitir solo cookies necesarias')]").click()
#       8     username=driver.find_element_by_css_selector("input[name='username']")
#
# KeyboardInterrupt:

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
def Webscrappingtsf():
    Modelo2=[]
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for i in tqdm(dataFashion['Account']):
        try:
            i=i.replace('</td>','')
            driver.get("https://thesocialflame.com/influencer/" + i)
            time.sleep(5)
            content = driver.find_element_by_xpath('//*[@id="top"]/div/div[3]/div[2]/p[1]')
            time.sleep(10)
        except:
            Modelo2.append('Unknown')
    return Modelo2

# %%
Webscrappingtsf()

# %%
column_names = ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10","Marcas11"]
df = pd.DataFrame(columns = column_names)
s=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s)
Etiquetados=[]
for i in tqdm(dataFashionspa['Account2']):
    try:
        driver.get("https://thesocialflame.com/influencer/"+ i)
        time.sleep(5)
        content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
        time.sleep(10)
        tokens = nltk.word_tokenize(content)
        if i.startswith("@"):
            Etiquetados.append(i)
            r = re.compile("\A@")
            newlist = list(filter(r.match, content))
            df = df.append(pd.Series(Etiquetados, index=df.columns[:len(Etiquetados)]), ignore_index=True)
    except:
        df = df.append('unknown')

# %%
lists = [[] for i in xrange(num_lists)]

# %%
column_names = ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10","Marcas11"]
df2 = pd.DataFrame(columns = column_names)
s=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s)
Etiquetados=[]
Etiquetados2=[]
def ultimostags(x):
    for a in tqdm(x):
        Etiquetados=[]
        driver.get("https://thesocialflame.com/influencer/" + a)
        time.sleep(3)
        try:
            content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
        except:
            content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text 
        time.sleep(3)
        for i in content.split():
            if i.startswith("@"):
                Etiquetados.append(i)     
        Etiquetados2.append(Etiquetados[0:10])

    data = pd.DataFrame(Etiquetados2,columns= ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10"])
    data.drop_duplicates()

# %%
s=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s)
Etiquetados=[]
Etiquetados2=[]
def ultimoshashtags(x):
    for a in tqdm(x):
        Etiquetados=[]
        driver.get("https://thesocialflame.com/influencer/" + a)
        time.sleep(3)
        try:
            content = driver.find_element_by_xpath('/html/body/main/div/div[3]/div[2]/p[1]').text
        except:
            content = driver.find_element_by_xpath('/html/body/main/div/div[2]/div[2]/p[1]').text 
        time.sleep(3)
        for i in content.split():
            if i.startswith("#"):
                Etiquetados.append(i)     
        Etiquetados2.append(Etiquetados[0:10])

    data = pd.DataFrame(Etiquetados2,columns= ["Hashtag1", "Hashtag2", "Hashtag3", "Hashtag4","Hashtag5", "Hashtag6", "Hashtag7", "Hashtag8", "Hashtag9", "Hashtag10"])
    data.drop_duplicates()

# %%
Etiquetados

# %%
data.drop_duplicates()

# %%
pd.concat([pd.DataFrame([i], columns=['A']) for i in range(5)], ignore_index=True)

# %%
df2

# %%
tokens = nltk.word_tokenize(content)

# %%
tokens

# %%
import nltk

# %%
import re

# %%
r = re.compile("\A@")
newlist = list(filter(r.match, content)) # Read Note

# %%
str(content)

# %%
Etiquetados=[]
for i in content.split():
    if i.startswith("@"):
        Etiquetados.append(i)

# %%
Etiquetados

# %%
column_names = ["Marcas1", "Marcas2", "Marcas3", "Marcas4","Marcas5", "Marcas6", "Marcas7", "Marcas8", "Marcas9", "Marcas10","Marcas11"]
df = pd.DataFrame(columns = column_names)
df = df.append(pd.Series(Etiquetados, index=df.columns[:len(Etiquetados)]), ignore_index=True)

# %%
df = df.append(pd.Series(Etiquetados, index=df.columns[:len(Etiquetados)]), ignore_index=True)

# %%
df

# %%
for i in content.split():
    if i.startswith("#"):
        print(i)

# %%
def females(x):
    females=[]
    df2 = pd.DataFrame(columns = column_names)
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for i in tqdm(x):
        driver.get("https://starngage.com/app/es/influencers/" + i)
        time.sleep(11)
        try:
            content = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div/div[2]/div[3]/div[1]/div/div/div[2]').text
            females.append(content)
        except:
            females.append('Unknown')
    
    females=pd.DataFrame(females)
    return females

# %%
def tiktok(x):
    tiktok=[]
    df2 = pd.DataFrame(columns = column_names)
    s=Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=s)
    for i in tqdm(x):
        driver.get("https://hypeauditor.com/es/preview/" + i)
        time.sleep(30)
        try:
            content = driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div[1]').text
            tiktok.append(content)
        except:
            tiktok.append('Unknown')
    
    tiktok=pd.DataFrame(tiktok)
    return tiktok

# %%
aaaa=tiktok(Fashion['Account2'][0:2])
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/marcpuyoliniesta/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
#   0%|                                                     | 0/2 [00:00<?, ?it/s]/var/folders/js/3prtlh997knckqf8p2nq_dz80000gn/T/ipykernel_783/5830468.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   content = driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div[1]').text
# 100%|█████████████████████████████████████████████| 2/2 [01:01<00:00, 30.71s/it]

# %%
aaaa
# Out:
#          0
# 0  Unknown
# 1  Unknown
